# %% [markdown]
# <a href="https://colab.research.google.com/github/mairapineda/Deep_Learning/blob/main/P2_2_PLN_redes_neuronales_recurrentes_(RNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #P0. Introducción -PLN
#
# ---
#
# En la creación de redes neuronales necesitamos dos tipos de IA, para reconocer patrones o generar nuevos:
#
# *   Las que no tienen memoria, identifica el patrón y ya!...ejemplo las de visión artificial
# *   Las de memoria corta (Long Short Term Memory)...PLN
# *   Las que requieren mucha memoria (aprenden casi todo...BERT)...PLN y visión artificial.

# %% [markdown]
# **Caso de estudio: generación de texto**
#
# ---
#
#
# Cualquier dato que se necesite procesar (sonido, imágenes, texto) primero debe ser convertido en un tensor numérico, un paso llamado “vectorización” (One-hot Encoding y WordEmbedding) de datos (y en nuestro ejemplo previamente las letras deben ser pasadas a valores numéricos

# %% [markdown]
# Para este ejemplo usaremos “*Character level language model*” propuesto por Andrej Karpathy en su artículo "*The Unreasonable Effectiveness of Recurrent Neural Networks*"(y parcialmente basado en su implementado en el tutorial "*Generate text with an RNN*" de la web de TensorFlow:
#
# Consiste en darle a la RNN una palabra y se le pide que modele la distribución de probabilidad del siguiente carácter que le correspondería a la secuencia de caracteres anteriores:
#
# Como ejemplo, supongamos que solo tenemos un vocabulario de cuatro letras posibles [“a”,”h”,”l”,”o”], y queremos entrenar a una RNN en la secuencia de entrenamiento “hola”. Esta secuencia de entrenamiento es, de hecho, una fuente de 3 ejemplos de entrenamiento por separado: La probabilidad de “o” debería ser verosímil dada el contexto de “h”, “l” debería ser verosímil en el contexto de “ho”, y finalmente “a” debería ser también verosímil dado el contexto de “hol”.
#
#
# ---
# *   https://unipython.com/generacion-de-textos-con-inteligencia-artificial/
# *    https://medium.com/analytics-vidhya/solution-to-tensorflow-2-not-using-gpu-119fb3e04daa (https://www.youtube.com/watch?v=kaQCdv46OBA&ab_channel=JeffHeaton)

# %% [markdown]
# #EJEMPLO 1: Prediciendo un texto (cuento los tres cerditos).

# %%
# !kill -9 -1 #reiniciando la maquina virtual

# %% [markdown]
# ##P0. importando librerias

# %% [markdown]
# ###Librerias genericas

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# absl-py                       1.0.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.11.4
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.4.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.1.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.4
# branca                        0.4.2
# bs4                           0.0.1
# CacheControl                  0.12.10
# cached-property               1.5.2
# cachetools                    4.2.4
# catalogue                     1.0.0
# certifi                       2021.10.8
# cffi                          1.15.0
# cftime                        1.6.0
# chardet                       3.0.4
# charset-normalizer            2.0.12
# click                         7.1.2
# cloudpickle                   1.3.0
# cmake                         3.12.0
# cmdstanpy                     0.9.5
# colorcet                      3.0.0
# colorlover                    0.3.0
# community                     1.0.0b1
# contextlib2                   0.5.5
# convertdate                   2.4.0
# coverage                      3.7.1
# coveralls                     0.5
# crcmod                        1.7
# cufflinks                     0.17.3
# cupy-cuda111                  9.4.0
# cvxopt                        1.2.7
# cvxpy                         1.0.31
# cycler                        0.11.0
# cymem                         2.0.6
# Cython                        0.29.28
# daft                          0.0.4
# dask                          2.12.0
# datascience                   0.10.6
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.7.1
# descartes                     1.1.0
# dill                          0.3.4
# distributed                   1.25.3
# dlib                          19.18.0
# dm-tree                       0.1.6
# docopt                        0.6.2
# docutils                      0.17.1
# dopamine-rl                   1.0.5
# earthengine-api               0.1.303
# easydict                      1.9
# ecos                          2.0.10
# editdistance                  0.5.3
# en-core-web-sm                2.2.5
# entrypoints                   0.4
# ephem                         4.1.3
# et-xmlfile                    1.1.0
# fa2                           0.3.5
# fastai                        1.0.61
# fastdtw                       0.3.4
# fastprogress                  1.0.2
# fastrlock                     0.8
# fbprophet                     0.7.1
# feather-format                0.4.1
# filelock                      3.6.0
# firebase-admin                4.4.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.4
# flatbuffers                   2.0
# folium                        0.8.3
# future                        0.16.0
# gast                          0.5.3
# GDAL                          2.2.2
# gdown                         4.2.2
# gensim                        3.6.0
# geographiclib                 1.52
# geopy                         1.17.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               1.26.3
# google-api-python-client      1.12.11
# google-auth                   1.35.0
# google-auth-httplib2          0.0.4
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         1.21.0
# google-cloud-bigquery-storage 1.1.0
# google-cloud-core             1.0.3
# google-cloud-datastore        1.8.0
# google-cloud-firestore        1.7.0
# google-cloud-language         1.2.0
# google-cloud-storage          1.18.1
# google-cloud-translate        1.5.0
# google-colab                  1.0.0
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.56.0
# googledrivedownloader         0.4
# graphviz                      0.10.1
# greenlet                      1.1.2
# grpcio                        1.44.0
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.17.3
# h5py                          3.1.0
# HeapDict                      1.0.1
# hijri-converter               2.2.3
# holidays                      0.10.5.2
# holoviews                     1.14.8
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httplib2shim                  0.0.3
# humanize                      0.5.1
# hyperopt                      0.1.2
# ideep4py                      2.0.0.post3
# idna                          2.10
# imageio                       2.4.1
# imagesize                     1.3.0
# imbalanced-learn              0.8.1
# imblearn                      0.0
# imgaug                        0.2.9
# importlib-metadata            4.11.3
# importlib-resources           5.4.0
# imutils                       0.5.4
# inflect                       2.1.0
# iniconfig                     1.1.1
# intel-openmp                  2022.0.2
# intervaltree                  2.1.0
# ipykernel                     4.10.1
# ipython                       5.5.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.7.0
# itsdangerous                  1.1.0
# jax                           0.3.4
# jaxlib                        0.3.2+cuda11.cudnn805
# jedi                          0.18.1
# jieba                         0.42.1
# Jinja2                        2.11.3
# joblib                        1.1.0
# jpeg4py                       0.1.4
# jsonschema                    4.3.3
# jupyter                       1.0.0
# jupyter-client                5.3.5
# jupyter-console               5.2.0
# jupyter-core                  4.9.2
# jupyterlab-pygments           0.1.2
# jupyterlab-widgets            1.1.0
# kaggle                        1.5.12
# kapre                         0.3.7
# keras                         2.8.0
# Keras-Preprocessing           1.1.2
# keras-vis                     0.4.1
# kiwisolver                    1.4.0
# korean-lunar-calendar         0.2.1
# libclang                      13.0.0
# librosa                       0.8.1
# lightgbm                      2.2.3
# llvmlite                      0.34.0
# lmdb                          0.99
# LunarCalendar                 0.0.9
# lxml                          4.2.6
# Markdown                      3.3.6
# MarkupSafe                    2.0.1
# matplotlib                    3.2.2
# matplotlib-inline             0.1.3
# matplotlib-venn               0.11.6
# missingno                     0.5.1
# mistune                       0.8.4
# mizani                        0.6.0
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                8.12.0
# moviepy                       0.2.3.5
# mpmath                        1.2.1
# msgpack                       1.0.3
# multiprocess                  0.70.12.2
# multitasking                  0.0.10
# murmurhash                    1.0.6
# music21                       5.5.0
# natsort                       5.5.0
# nbclient                      0.5.13
# nbconvert                     5.6.1
# nbformat                      5.2.0
# nest-asyncio                  1.5.4
# netCDF4                       1.5.8
# networkx                      2.6.3
# nibabel                       3.0.2
# nltk                          3.2.5
# notebook                      5.3.1
# numba                         0.51.2
# numexpr                       2.8.1
# numpy                         1.21.5
# nvidia-ml-py3                 7.352.0
# oauth2client                  4.1.3
# oauthlib                      3.2.0
# okgrade                       0.4.3
# opencv-contrib-python         4.1.2.30
# opencv-python                 4.1.2.30
# openpyxl                      3.0.9
# opt-einsum                    3.3.0
# osqp                          0.6.2.post0
# packaging                     21.3
# palettable                    3.3.0
# pandas                        1.3.5
# pandas-datareader             0.9.0
# pandas-gbq                    0.13.3
# pandas-profiling              1.4.1
# pandocfilters                 1.5.0
# panel                         0.12.1
# param                         1.12.0
# parso                         0.8.3
# pathlib                       1.0.1
# patsy                         0.5.2
# pep517                        0.12.0
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        7.1.2
# pip                           21.1.3
# pip-tools                     6.2.0
# plac                          1.1.3
# plotly                        5.5.0
# plotnine                      0.6.0
# pluggy                        0.7.1
# pooch                         1.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.1
# preshed                       3.0.6
# prettytable                   3.2.0
# progressbar2                  3.38.0
# prometheus-client             0.13.1
# promise                       2.3
# prompt-toolkit                1.0.18
# protobuf                      3.17.3
# psutil                        5.4.8
# psycopg2                      2.7.6.1
# ptyprocess                    0.7.0
# py                            1.11.0
# pyarrow                       6.0.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.4
# pycparser                     2.21
# pyct                          0.4.8
# pydata-google-auth            1.4.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyerfa                        2.0.0.1
# pyglet                        1.5.0
# Pygments                      2.6.1
# pygobject                     3.26.1
# pymc3                         3.11.4
# PyMeeus                       0.5.11
# pymongo                       4.0.2
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.7
# pyrsistent                    0.18.1
# pysndfile                     1.3.8
# PySocks                       1.7.1
# pystan                        2.19.1.1
# pytest                        3.6.4
# python-apt                    0.0.0
# python-chess                  0.23.11
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                6.1.1
# python-utils                  3.1.0
# pytz                          2018.9
# pyviz-comms                   2.1.0
# PyWavelets                    1.3.0
# PyYAML                        3.13
# pyzmq                         22.3.0
# qdldl                         0.1.5.post0
# qtconsole                     5.2.2
# QtPy                          2.0.1
# regex                         2019.12.20
# requests                      2.23.0
# requests-oauthlib             1.3.1
# resampy                       0.2.2
# rpy2                          3.4.5
# rsa                           4.8
# scikit-image                  0.18.3
# scikit-learn                  1.0.2
# scipy                         1.4.1
# screen-resolution-extra       0.0.0
# scs                           3.2.0
# seaborn                       0.11.2
# semver                        2.13.0
# Send2Trash                    1.8.0
# setuptools                    57.4.0
# setuptools-git                1.2
# Shapely                       1.8.1.post1
# simplegeneric                 0.8.1
# six                           1.15.0
# sklearn                       0.0
# sklearn-pandas                1.8.0
# smart-open                    5.2.1
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# SoundFile                     0.10.3.post1
# soupsieve                     2.3.1
# spacy                         2.2.4
# Sphinx                        1.8.6
# sphinxcontrib-serializinghtml 1.1.5
# sphinxcontrib-websupport      1.2.4
# SQLAlchemy                    1.4.32
# sqlparse                      0.4.2
# srsly                         1.0.5
# statsmodels                   0.10.2
# sympy                         1.7.1
# tables                        3.7.0
# tabulate                      0.8.9
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.8.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.8.0
# tensorflow-datasets           4.0.1
# tensorflow-estimator          2.8.0
# tensorflow-gcs-config         2.8.0
# tensorflow-hub                0.12.0
# tensorflow-io-gcs-filesystem  0.24.0
# tensorflow-metadata           1.7.0
# tensorflow-probability        0.16.0
# termcolor                     1.1.0
# terminado                     0.13.3
# testpath                      0.6.0
# text-unidecode                1.3
# textblob                      0.15.3
# Theano-PyMC                   1.1.2
# thinc                         7.4.0
# threadpoolctl                 3.1.0
# tifffile                      2021.11.2
# tomli                         2.0.1
# toolz                         0.11.2
# torch                         1.10.0+cu111
# torchaudio                    0.10.0+cu111
# torchsummary                  1.5.1
# torchtext                     0.11.0
# torchvision                   0.11.1+cu111
# tornado                       5.1.1
# tqdm                          4.63.0
# traitlets                     5.1.1
# tweepy                        3.10.0
# typeguard                     2.7.1
# typing-extensions             3.10.0.2
# tzlocal                       1.5.1
# uritemplate                   3.0.1
# urllib3                       1.24.3
# vega-datasets                 0.9.0
# wasabi                        0.9.0
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.37.1
# widgetsnbextension            3.6.0
# wordcloud                     1.5.0
# wrapt                         1.14.0
# xarray                        0.18.2
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.1.0
# xlwt                          1.3.0
# yellowbrick                   1.4
# zict                          2.1.0
# zipp                          3.7.0

# %%
import requests
import io
import os

import numpy as np
import sys

#librerías para graficar
import matplotlib.pyplot as plt
                 
plt.rcParams['figure.figsize'] = (16, 9)  #ver graficas grandes 
plt.style.use('ggplot')
#guardar las imagenes y tablas en el cuaderno de jupyter
# %matplotlib inline

# %% [markdown]
# ###librerias para DL (Deep Learning)

# %%
import tensorflow as tf

# %%
print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# Version:  2.8.0
# Eager mode:  True
# GPU is available

# %% [markdown]
# Verificando los recursos de maquina para entrenar:
#
# ---
# **CUDA (GPU-NVIDIA):**
# CUDA es una plataforma de computación paralela y un modelo de programación que hace que el uso de una GPU para la computación de propósito general sea simple y elegante

# %%
print("-------------------------------RAM------------------------------")
# !cat /proc/meminfo  #cuanta memoria tenemos?
print("-----------------------------PROCESADOR-------------------------")
# !cat /proc/cpuinfo  # que procesador tenemos?
print("-------------------------------CUDA-----------------------------")
# !nvcc -V   # version de CUDA
# Out:
# -------------------------------RAM------------------------------
# MemTotal:       13302920 kB
# MemFree:        10046028 kB
# MemAvailable:   11958280 kB
# Buffers:          114212 kB
# Cached:          1903788 kB
# SwapCached:            0 kB
# Active:          1526920 kB
# Inactive:        1456056 kB
# Active(anon):     875748 kB
# Inactive(anon):      476 kB
# Active(file):     651172 kB
# Inactive(file):  1455580 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              1052 kB
# Writeback:             0 kB
# AnonPages:        964876 kB
# Mapped:           473900 kB
# Shmem:              1204 kB
# KReclaimable:      93952 kB
# Slab:             141324 kB
# SReclaimable:      93952 kB
# SUnreclaim:        47372 kB
# KernelStack:        5072 kB
# PageTables:        12672 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6651460 kB
# Committed_AS:    3356012 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       46632 kB
# VmallocChunk:          0 kB
# Percpu:             1448 kB
# AnonHugePages:      2048 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      189248 kB
# DirectMap2M:     7147520 kB
# DirectMap1G:     8388608 kB
# -----------------------------PROCESADOR-------------------------
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# -------------------------------CUDA-----------------------------
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# ###Activando la GPU
#
# ---
# Logra aumentar la velocidad de entrenamiento en un 600% en PLN (RNN) y un 1000% en visión por computadores (CNN)

# %%
tf.device('/GPU:0')# OJO: esto es para que tensorflow utilice la GPU (aumenta la velocidad de entrenamiento en un 600%)

# %% [markdown]
# ##P1. Descarga y preprocesado de los datos

# %%
fileUrl     ='https://raw.githubusercontent.com/luisFernandoCastellanosG/Machine_learning/master/2-Deep_Learning/PLN/Datasets/Panel_Txt_Files/Tres_cerditos.txt'
fileContent = tf.keras.utils.get_file('Tres_cerditos.txt',fileUrl)
texto       = open(fileContent, 'rb').read().decode(encoding='utf-8')
raw_text    = texto.lower()
print(raw_text)
# Out:
# Downloading data from https://raw.githubusercontent.com/luisFernandoCastellanosG/Machine_learning/master/2-Deep_Learning/PLN/Datasets/Panel_Txt_Files/Tres_cerditos.txt
# 16384/3231 [========================================================================================================================================================] - 0s 0us/step
# había una vez tres cerditos que eran hermanos y se fueron por el mundo a conseguir fortuna. el más grande les dijo a sus hermanos que sería bueno que se pusieran a construir sus propias casas para estar protegidos. a los otros dos les pareció una buena idea, y se pusieron manos a la obra, cada uno construyó su casita.  - la mía será de paja - dijo el más pequeño-, la paja es blanda y se puede sujetar con facilidad. terminaré muy pronto y podré ir a jugar. el hermano mediano decidió que su casa sería de madera:  - puedo encontrar un montón de madera por los alrededores - explicó
# a sus hermanos, - construiré mi casa en un santiamén con todos estos troncos y me iré también a jugar.  cuando las tres casitas estuvieron terminadas, los cerditos cantaban y bailaban en la puerta, felices por haber acabado con el problema:  -¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo feroz! detrás de un árbol grande apareció el lobo, rugiendo de hambre y gritando:  - cerditos, ¡me los voy a comer! cada uno se escondió en su casa, pensando que estaban a salvo, pero el lobo feroz se encaminó a la casita de paja del hermano pequeño y en la puerta aulló:  - ¡cerdito, ábreme la puerta!  - no, no, no, no te voy a abrir. - pues si no me abres... ¡soplaré y soplaré y la casita derribaré! y sopló con todas sus fuerzas, sopló y sopló y la casita de paja se vino abajo. el cerdito pequeño corrió lo más rápido que pudo y entró en la casa de madera del hermano mediano. - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo feroz! - cantaban desde dentro los cerditos.  de nuevo el lobo, más enfurecido que antes al sentirse engañado, se colocó delante de la puerta y comenzó a soplar y soplar gruñendo: - ¡cerditos, abridme la puerta! - no, no, no, no te vamos a abrir. - pues si no me abrís...
# ¡soplaré y soplaré y la casita derribaré! la madera crujió, y las paredes cayeron y los dos cerditos corrieron a refugiarse en la casa de ladrillo de su hermano mayor.  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo feroz! - cantaban desde dentro los cerditos. el lobo estaba realmente enfadado y hambriento, y ahora deseaba comerse a los tres cerditos más que nunca, y frente a la puerta dijo:  - ¡cerditos, abridme la puerta! - no, no, no, no te vamos a abrir.  - pues si no me abrís... ¡soplaré y soplaré y la casita derribaré!  y se puso a soplar tan fuerte como el viento de invierno. sopló y sopló, pero la casita de ladrillos era muy resistente y no conseguía derribarla. decidió trepar por la pared y entrar por la chimenea. se deslizó hacia abajo... y cayó en el caldero donde el cerdito mayor estaba hirviendo sopa de nabos. escaldado y con el estómago vacío salió huyendo hacia el lago. los cerditos no lo volvieron a ver.  el mayor de ellos regañó a los otros dos por haber sido tan perezosos y poner en peligro sus propias vidas, y si algún día vais por el bosque y veis tres cerdos, sabréis que son los tres cerditos porque les gusta cantar:  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo feroz!

# %% [markdown]
# ##P2. pasar el texto a números
#
# ---
# Sin importan el origen de la informacción (video, sonido, sensor, texto)...siempre debemos convertirlos en datos númericos.

# %%
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
print(chars)
print(char_to_int)
# Out:
# ['\n', '\r', ' ', '!', ',', '-', '.', ':', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'v', 'x', 'y', 'z', '¡', 'á', 'é', 'í', 'ñ', 'ó', 'ú']
# {'\n': 0, '\r': 1, ' ': 2, '!': 3, ',': 4, '-': 5, '.': 6, ':': 7, 'a': 8, 'b': 9, 'c': 10, 'd': 11, 'e': 12, 'f': 13, 'g': 14, 'h': 15, 'i': 16, 'j': 17, 'l': 18, 'm': 19, 'n': 20, 'o': 21, 'p': 22, 'q': 23, 'r': 24, 's': 25, 't': 26, 'u': 27, 'v': 28, 'x': 29, 'y': 30, 'z': 31, '¡': 32, 'á': 33, 'é': 34, 'í': 35, 'ñ': 36, 'ó': 37, 'ú': 38}

# %%
n_chars = len(raw_text)
n_vocab = len(chars)
print("En total hay %d caracteres, y el diccionario tiene un tamaño de %d caracteres." % (n_chars, n_vocab))
# Out:
# En total hay 3141 caracteres, y el diccionario tiene un tamaño de 39 caracteres.

# %% [markdown]
# ###P2.1 Dividimos el texto en secuencias:
# ---
# Dividimos el texto en estas secuencias (adrede), convertimos los caracteres a números enteros usando nuestra tabla de búsqueda que preparamos anteriormente

# %%
# preparar el conjunto de datos de los pares de entrada a salida codificados como enteros
seq_length = 50   #largo de las secciones de texto que usaremos para entrenar
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	print("Seq(",i,")=",raw_text[i:i + seq_length],"---->",raw_text[i + seq_length])
	seq_in 	= raw_text[i:i + seq_length]         					#secuencia de entrada
	seq_out = raw_text[i + seq_length]										#siguiente letra despues de la secuencia (la que el va a aprender)
	dataX.append([char_to_int[char] for char in seq_in])  # convertimos cada secuencia en numeros
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print ("Se generaron ",format(n_patterns) ," secuencias texto de un tamaño de ",seq_length," caracteres" )
print("Como se ven los datos de X convertidos a números\n")
print(dataX)
print("\nComo se ven los datos de Y convertidos a números\n")
print(dataY)
# Out:
# Seq( 0 )= había una vez tres cerditos que eran hermanos y se ---->
# Seq( 1 )= abía una vez tres cerditos que eran hermanos y se  ----> f
# Seq( 2 )= bía una vez tres cerditos que eran hermanos y se f ----> u
# Seq( 3 )= ía una vez tres cerditos que eran hermanos y se fu ----> e
# Seq( 4 )= a una vez tres cerditos que eran hermanos y se fue ----> r
# Seq( 5 )=  una vez tres cerditos que eran hermanos y se fuer ----> o
# Seq( 6 )= una vez tres cerditos que eran hermanos y se fuero ----> n
# Seq( 7 )= na vez tres cerditos que eran hermanos y se fueron ---->
# Seq( 8 )= a vez tres cerditos que eran hermanos y se fueron  ----> p
# Seq( 9 )=  vez tres cerditos que eran hermanos y se fueron p ----> o
# Seq( 10 )= vez tres cerditos que eran hermanos y se fueron po ----> r
# Seq( 11 )= ez tres cerditos que eran hermanos y se fueron por ---->
# Seq( 12 )= z tres cerditos que eran hermanos y se fueron por  ----> e
# Seq( 13 )=  tres cerditos que eran hermanos y se fueron por e ----> l
# Seq( 14 )= tres cerditos que eran hermanos y se fueron por el ---->
# Seq( 15 )= res cerditos que eran hermanos y se fueron por el  ----> m
# Seq( 16 )= es cerditos que eran hermanos y se fueron por el m ----> u
# Seq( 17 )= s cerditos que eran hermanos y se fueron por el mu ----> n
# Seq( 18 )=  cerditos que eran hermanos y se fueron por el mun ----> d
# Seq( 19 )= cerditos que eran hermanos y se fueron por el mund ----> o
# Seq( 20 )= erditos que eran hermanos y se fueron por el mundo ---->
# Seq( 21 )= rditos que eran hermanos y se fueron por el mundo  ----> a
# Seq( 22 )= ditos que eran hermanos y se fueron por el mundo a ---->
# Seq( 23 )= itos que eran hermanos y se fueron por el mundo a  ----> c
# Seq( 24 )= tos que eran hermanos y se fueron por el mundo a c ----> o
# Seq( 25 )= os que eran hermanos y se fueron por el mundo a co ----> n
# Seq( 26 )= s que eran hermanos y se fueron por el mundo a con ----> s
# Seq( 27 )=  que eran hermanos y se fueron por el mundo a cons ----> e
# Seq( 28 )= que eran hermanos y se fueron por el mundo a conse ----> g
# Seq( 29 )= ue eran hermanos y se fueron por el mundo a conseg ----> u
# Seq( 30 )= e eran hermanos y se fueron por el mundo a consegu ----> i
# Seq( 31 )=  eran hermanos y se fueron por el mundo a consegui ----> r
# Seq( 32 )= eran hermanos y se fueron por el mundo a conseguir ---->
# Seq( 33 )= ran hermanos y se fueron por el mundo a conseguir  ----> f
# Seq( 34 )= an hermanos y se fueron por el mundo a conseguir f ----> o
# Seq( 35 )= n hermanos y se fueron por el mundo a conseguir fo ----> r
# Seq( 36 )=  hermanos y se fueron por el mundo a conseguir for ----> t
# Seq( 37 )= hermanos y se fueron por el mundo a conseguir fort ----> u
# Seq( 38 )= ermanos y se fueron por el mundo a conseguir fortu ----> n
# Seq( 39 )= rmanos y se fueron por el mundo a conseguir fortun ----> a
# Seq( 40 )= manos y se fueron por el mundo a conseguir fortuna ----> .
# Seq( 41 )= anos y se fueron por el mundo a conseguir fortuna. ---->
# Seq( 42 )= nos y se fueron por el mundo a conseguir fortuna.  ----> e
# Seq( 43 )= os y se fueron por el mundo a conseguir fortuna. e ----> l
# Seq( 44 )= s y se fueron por el mundo a conseguir fortuna. el ---->
# Seq( 45 )=  y se fueron por el mundo a conseguir fortuna. el  ----> m
# Seq( 46 )= y se fueron por el mundo a conseguir fortuna. el m ----> á
# Seq( 47 )=  se fueron por el mundo a conseguir fortuna. el má ----> s
# Seq( 48 )= se fueron por el mundo a conseguir fortuna. el más ---->
# Seq( 49 )= e fueron por el mundo a conseguir fortuna. el más  ----> g
# Seq( 50 )=  fueron por el mundo a conseguir fortuna. el más g ----> r
# Seq( 51 )= fueron por el mundo a conseguir fortuna. el más gr ----> a
# Seq( 52 )= ueron por el mundo a conseguir fortuna. el más gra ----> n
# Seq( 53 )= eron por el mundo a conseguir fortuna. el más gran ----> d
# Seq( 54 )= ron por el mundo a conseguir fortuna. el más grand ----> e
# Seq( 55 )= on por el mundo a conseguir fortuna. el más grande ---->
# Seq( 56 )= n por el mundo a conseguir fortuna. el más grande  ----> l
# Seq( 57 )=  por el mundo a conseguir fortuna. el más grande l ----> e
# Seq( 58 )= por el mundo a conseguir fortuna. el más grande le ----> s
# Seq( 59 )= or el mundo a conseguir fortuna. el más grande les ---->
# Seq( 60 )= r el mundo a conseguir fortuna. el más grande les  ----> d
# Seq( 61 )=  el mundo a conseguir fortuna. el más grande les d ----> i
# Seq( 62 )= el mundo a conseguir fortuna. el más grande les di ----> j
# Seq( 63 )= l mundo a conseguir fortuna. el más grande les dij ----> o
# Seq( 64 )=  mundo a conseguir fortuna. el más grande les dijo ---->
# Seq( 65 )= mundo a conseguir fortuna. el más grande les dijo  ----> a
# Seq( 66 )= undo a conseguir fortuna. el más grande les dijo a ---->
# Seq( 67 )= ndo a conseguir fortuna. el más grande les dijo a  ----> s
# Seq( 68 )= do a conseguir fortuna. el más grande les dijo a s ----> u
# Seq( 69 )= o a conseguir fortuna. el más grande les dijo a su ----> s
# Seq( 70 )=  a conseguir fortuna. el más grande les dijo a sus ---->
# Seq( 71 )= a conseguir fortuna. el más grande les dijo a sus  ----> h
# Seq( 72 )=  conseguir fortuna. el más grande les dijo a sus h ----> e
# Seq( 73 )= conseguir fortuna. el más grande les dijo a sus he ----> r
# Seq( 74 )= onseguir fortuna. el más grande les dijo a sus her ----> m
# Seq( 75 )= nseguir fortuna. el más grande les dijo a sus herm ----> a
# Seq( 76 )= seguir fortuna. el más grande les dijo a sus herma ----> n
# Seq( 77 )= eguir fortuna. el más grande les dijo a sus herman ----> o
# Seq( 78 )= guir fortuna. el más grande les dijo a sus hermano ----> s
# Seq( 79 )= uir fortuna. el más grande les dijo a sus hermanos ---->
# Seq( 80 )= ir fortuna. el más grande les dijo a sus hermanos  ----> q
# Seq( 81 )= r fortuna. el más grande les dijo a sus hermanos q ----> u
# Seq( 82 )=  fortuna. el más grande les dijo a sus hermanos qu ----> e
# Seq( 83 )= fortuna. el más grande les dijo a sus hermanos que ---->
# Seq( 84 )= ortuna. el más grande les dijo a sus hermanos que  ----> s
# Seq( 85 )= rtuna. el más grande les dijo a sus hermanos que s ----> e
# Seq( 86 )= tuna. el más grande les dijo a sus hermanos que se ----> r
# Seq( 87 )= una. el más grande les dijo a sus hermanos que ser ----> í
# Seq( 88 )= na. el más grande les dijo a sus hermanos que serí ----> a
# Seq( 89 )= a. el más grande les dijo a sus hermanos que sería ---->
# Seq( 90 )= . el más grande les dijo a sus hermanos que sería  ----> b
# Seq( 91 )=  el más grande les dijo a sus hermanos que sería b ----> u
# Seq( 92 )= el más grande les dijo a sus hermanos que sería bu ----> e
# Seq( 93 )= l más grande les dijo a sus hermanos que sería bue ----> n
# Seq( 94 )=  más grande les dijo a sus hermanos que sería buen ----> o
# Seq( 95 )= más grande les dijo a sus hermanos que sería bueno ---->
# Seq( 96 )= ás grande les dijo a sus hermanos que sería bueno  ----> q
# Seq( 97 )= s grande les dijo a sus hermanos que sería bueno q ----> u
# Seq( 98 )=  grande les dijo a sus hermanos que sería bueno qu ----> e
# Seq( 99 )= grande les dijo a sus hermanos que sería bueno que ---->
# Seq( 100 )= rande les dijo a sus hermanos que sería bueno que  ----> s
# Seq( 101 )= ande les dijo a sus hermanos que sería bueno que s ----> e
# Seq( 102 )= nde les dijo a sus hermanos que sería bueno que se ---->
# Seq( 103 )= de les dijo a sus hermanos que sería bueno que se  ----> p
# Seq( 104 )= e les dijo a sus hermanos que sería bueno que se p ----> u
# Seq( 105 )=  les dijo a sus hermanos que sería bueno que se pu ----> s
# Seq( 106 )= les dijo a sus hermanos que sería bueno que se pus ----> i
# Seq( 107 )= es dijo a sus hermanos que sería bueno que se pusi ----> e
# Seq( 108 )= s dijo a sus hermanos que sería bueno que se pusie ----> r
# Seq( 109 )=  dijo a sus hermanos que sería bueno que se pusier ----> a
# Seq( 110 )= dijo a sus hermanos que sería bueno que se pusiera ----> n
# Seq( 111 )= ijo a sus hermanos que sería bueno que se pusieran ---->
# Seq( 112 )= jo a sus hermanos que sería bueno que se pusieran  ----> a
# Seq( 113 )= o a sus hermanos que sería bueno que se pusieran a ---->
# Seq( 114 )=  a sus hermanos que sería bueno que se pusieran a  ----> c
# Seq( 115 )= a sus hermanos que sería bueno que se pusieran a c ----> o
# Seq( 116 )=  sus hermanos que sería bueno que se pusieran a co ----> n
# Seq( 117 )= sus hermanos que sería bueno que se pusieran a con ----> s
# Seq( 118 )= us hermanos que sería bueno que se pusieran a cons ----> t
# Seq( 119 )= s hermanos que sería bueno que se pusieran a const ----> r
# Seq( 120 )=  hermanos que sería bueno que se pusieran a constr ----> u
# Seq( 121 )= hermanos que sería bueno que se pusieran a constru ----> i
# Seq( 122 )= ermanos que sería bueno que se pusieran a construi ----> r
# Seq( 123 )= rmanos que sería bueno que se pusieran a construir ---->
# Seq( 124 )= manos que sería bueno que se pusieran a construir  ----> s
# Seq( 125 )= anos que sería bueno que se pusieran a construir s ----> u
# Seq( 126 )= nos que sería bueno que se pusieran a construir su ----> s
# Seq( 127 )= os que sería bueno que se pusieran a construir sus ---->
# Seq( 128 )= s que sería bueno que se pusieran a construir sus  ----> p
# Seq( 129 )=  que sería bueno que se pusieran a construir sus p ----> r
# Seq( 130 )= que sería bueno que se pusieran a construir sus pr ----> o
# Seq( 131 )= ue sería bueno que se pusieran a construir sus pro ----> p
# Seq( 132 )= e sería bueno que se pusieran a construir sus prop ----> i
# Seq( 133 )=  sería bueno que se pusieran a construir sus propi ----> a
# Seq( 134 )= sería bueno que se pusieran a construir sus propia ----> s
# Seq( 135 )= ería bueno que se pusieran a construir sus propias ---->
# Seq( 136 )= ría bueno que se pusieran a construir sus propias  ----> c
# Seq( 137 )= ía bueno que se pusieran a construir sus propias c ----> a
# Seq( 138 )= a bueno que se pusieran a construir sus propias ca ----> s
# Seq( 139 )=  bueno que se pusieran a construir sus propias cas ----> a
# Seq( 140 )= bueno que se pusieran a construir sus propias casa ----> s
# Seq( 141 )= ueno que se pusieran a construir sus propias casas ---->
# Seq( 142 )= eno que se pusieran a construir sus propias casas  ----> p
# Seq( 143 )= no que se pusieran a construir sus propias casas p ----> a
# Seq( 144 )= o que se pusieran a construir sus propias casas pa ----> r
# Seq( 145 )=  que se pusieran a construir sus propias casas par ----> a
# Seq( 146 )= que se pusieran a construir sus propias casas para ---->
# Seq( 147 )= ue se pusieran a construir sus propias casas para  ----> e
# Seq( 148 )= e se pusieran a construir sus propias casas para e ----> s
# Seq( 149 )=  se pusieran a construir sus propias casas para es ----> t
# Seq( 150 )= se pusieran a construir sus propias casas para est ----> a
# Seq( 151 )= e pusieran a construir sus propias casas para esta ----> r
# Seq( 152 )=  pusieran a construir sus propias casas para estar ---->
# Seq( 153 )= pusieran a construir sus propias casas para estar  ----> p
# Seq( 154 )= usieran a construir sus propias casas para estar p ----> r
# Seq( 155 )= sieran a construir sus propias casas para estar pr ----> o
# Seq( 156 )= ieran a construir sus propias casas para estar pro ----> t
# Seq( 157 )= eran a construir sus propias casas para estar prot ----> e
# Seq( 158 )= ran a construir sus propias casas para estar prote ----> g
# Seq( 159 )= an a construir sus propias casas para estar proteg ----> i
# Seq( 160 )= n a construir sus propias casas para estar protegi ----> d
# Seq( 161 )=  a construir sus propias casas para estar protegid ----> o
# Seq( 162 )= a construir sus propias casas para estar protegido ----> s
# Seq( 163 )=  construir sus propias casas para estar protegidos ----> .
# Seq( 164 )= construir sus propias casas para estar protegidos. ---->
# Seq( 165 )= onstruir sus propias casas para estar protegidos.  ----> a
# Seq( 166 )= nstruir sus propias casas para estar protegidos. a ---->
# Seq( 167 )= struir sus propias casas para estar protegidos. a  ----> l
# Seq( 168 )= truir sus propias casas para estar protegidos. a l ----> o
# Seq( 169 )= ruir sus propias casas para estar protegidos. a lo ----> s
# Seq( 170 )= uir sus propias casas para estar protegidos. a los ---->
# Seq( 171 )= ir sus propias casas para estar protegidos. a los  ----> o
# Seq( 172 )= r sus propias casas para estar protegidos. a los o ----> t
# Seq( 173 )=  sus propias casas para estar protegidos. a los ot ----> r
# Seq( 174 )= sus propias casas para estar protegidos. a los otr ----> o
# Seq( 175 )= us propias casas para estar protegidos. a los otro ----> s
# Seq( 176 )= s propias casas para estar protegidos. a los otros ---->
# Seq( 177 )=  propias casas para estar protegidos. a los otros  ----> d
# Seq( 178 )= propias casas para estar protegidos. a los otros d ----> o
# Seq( 179 )= ropias casas para estar protegidos. a los otros do ----> s
# Seq( 180 )= opias casas para estar protegidos. a los otros dos ---->
# Seq( 181 )= pias casas para estar protegidos. a los otros dos  ----> l
# Seq( 182 )= ias casas para estar protegidos. a los otros dos l ----> e
# Seq( 183 )= as casas para estar protegidos. a los otros dos le ----> s
# Seq( 184 )= s casas para estar protegidos. a los otros dos les ---->
# Seq( 185 )=  casas para estar protegidos. a los otros dos les  ----> p
# Seq( 186 )= casas para estar protegidos. a los otros dos les p ----> a
# Seq( 187 )= asas para estar protegidos. a los otros dos les pa ----> r
# Seq( 188 )= sas para estar protegidos. a los otros dos les par ----> e
# Seq( 189 )= as para estar protegidos. a los otros dos les pare ----> c
# Seq( 190 )= s para estar protegidos. a los otros dos les parec ----> i
# Seq( 191 )=  para estar protegidos. a los otros dos les pareci ----> ó
# Seq( 192 )= para estar protegidos. a los otros dos les pareció ---->
# Seq( 193 )= ara estar protegidos. a los otros dos les pareció  ----> u
# Seq( 194 )= ra estar protegidos. a los otros dos les pareció u ----> n
# Seq( 195 )= a estar protegidos. a los otros dos les pareció un ----> a
# Seq( 196 )=  estar protegidos. a los otros dos les pareció una ---->
# Seq( 197 )= estar protegidos. a los otros dos les pareció una  ----> b
# Seq( 198 )= star protegidos. a los otros dos les pareció una b ----> u
# Seq( 199 )= tar protegidos. a los otros dos les pareció una bu ----> e
# Seq( 200 )= ar protegidos. a los otros dos les pareció una bue ----> n
# Seq( 201 )= r protegidos. a los otros dos les pareció una buen ----> a
# Seq( 202 )=  protegidos. a los otros dos les pareció una buena ---->
# Seq( 203 )= protegidos. a los otros dos les pareció una buena  ----> i
# Seq( 204 )= rotegidos. a los otros dos les pareció una buena i ----> d
# Seq( 205 )= otegidos. a los otros dos les pareció una buena id ----> e
# Seq( 206 )= tegidos. a los otros dos les pareció una buena ide ----> a
# Seq( 207 )= egidos. a los otros dos les pareció una buena idea ----> ,
# Seq( 208 )= gidos. a los otros dos les pareció una buena idea, ---->
# Seq( 209 )= idos. a los otros dos les pareció una buena idea,  ----> y
# Seq( 210 )= dos. a los otros dos les pareció una buena idea, y ---->
# Seq( 211 )= os. a los otros dos les pareció una buena idea, y  ----> s
# Seq( 212 )= s. a los otros dos les pareció una buena idea, y s ----> e
# Seq( 213 )= . a los otros dos les pareció una buena idea, y se ---->
# Seq( 214 )=  a los otros dos les pareció una buena idea, y se  ----> p
# Seq( 215 )= a los otros dos les pareció una buena idea, y se p ----> u
# Seq( 216 )=  los otros dos les pareció una buena idea, y se pu ----> s
# Seq( 217 )= los otros dos les pareció una buena idea, y se pus ----> i
# Seq( 218 )= os otros dos les pareció una buena idea, y se pusi ----> e
# Seq( 219 )= s otros dos les pareció una buena idea, y se pusie ----> r
# Seq( 220 )=  otros dos les pareció una buena idea, y se pusier ----> o
# Seq( 221 )= otros dos les pareció una buena idea, y se pusiero ----> n
# Seq( 222 )= tros dos les pareció una buena idea, y se pusieron ---->
# Seq( 223 )= ros dos les pareció una buena idea, y se pusieron  ----> m
# Seq( 224 )= os dos les pareció una buena idea, y se pusieron m ----> a
# Seq( 225 )= s dos les pareció una buena idea, y se pusieron ma ----> n
# Seq( 226 )=  dos les pareció una buena idea, y se pusieron man ----> o
# Seq( 227 )= dos les pareció una buena idea, y se pusieron mano ----> s
# Seq( 228 )= os les pareció una buena idea, y se pusieron manos ---->
# Seq( 229 )= s les pareció una buena idea, y se pusieron manos  ----> a
# Seq( 230 )=  les pareció una buena idea, y se pusieron manos a ---->
# Seq( 231 )= les pareció una buena idea, y se pusieron manos a  ----> l
# Seq( 232 )= es pareció una buena idea, y se pusieron manos a l ----> a
# Seq( 233 )= s pareció una buena idea, y se pusieron manos a la ---->
# Seq( 234 )=  pareció una buena idea, y se pusieron manos a la  ----> o
# Seq( 235 )= pareció una buena idea, y se pusieron manos a la o ----> b
# Seq( 236 )= areció una buena idea, y se pusieron manos a la ob ----> r
# Seq( 237 )= reció una buena idea, y se pusieron manos a la obr ----> a
# Seq( 238 )= eció una buena idea, y se pusieron manos a la obra ----> ,
# Seq( 239 )= ció una buena idea, y se pusieron manos a la obra, ---->
# Seq( 240 )= ió una buena idea, y se pusieron manos a la obra,  ----> c
# Seq( 241 )= ó una buena idea, y se pusieron manos a la obra, c ----> a
# Seq( 242 )=  una buena idea, y se pusieron manos a la obra, ca ----> d
# Seq( 243 )= una buena idea, y se pusieron manos a la obra, cad ----> a
# Seq( 244 )= na buena idea, y se pusieron manos a la obra, cada ---->
# Seq( 245 )= a buena idea, y se pusieron manos a la obra, cada  ----> u
# Seq( 246 )=  buena idea, y se pusieron manos a la obra, cada u ----> n
# Seq( 247 )= buena idea, y se pusieron manos a la obra, cada un ----> o
# Seq( 248 )= uena idea, y se pusieron manos a la obra, cada uno ---->
# Seq( 249 )= ena idea, y se pusieron manos a la obra, cada uno  ----> c
# Seq( 250 )= na idea, y se pusieron manos a la obra, cada uno c ----> o
# Seq( 251 )= a idea, y se pusieron manos a la obra, cada uno co ----> n
# Seq( 252 )=  idea, y se pusieron manos a la obra, cada uno con ----> s
# Seq( 253 )= idea, y se pusieron manos a la obra, cada uno cons ----> t
# Seq( 254 )= dea, y se pusieron manos a la obra, cada uno const ----> r
# Seq( 255 )= ea, y se pusieron manos a la obra, cada uno constr ----> u
# Seq( 256 )= a, y se pusieron manos a la obra, cada uno constru ----> y
# Seq( 257 )= , y se pusieron manos a la obra, cada uno construy ----> ó
# Seq( 258 )=  y se pusieron manos a la obra, cada uno construyó ---->
# Seq( 259 )= y se pusieron manos a la obra, cada uno construyó  ----> s
# Seq( 260 )=  se pusieron manos a la obra, cada uno construyó s ----> u
# Seq( 261 )= se pusieron manos a la obra, cada uno construyó su ---->
# Seq( 262 )= e pusieron manos a la obra, cada uno construyó su  ----> c
# Seq( 263 )=  pusieron manos a la obra, cada uno construyó su c ----> a
# Seq( 264 )= pusieron manos a la obra, cada uno construyó su ca ----> s
# Seq( 265 )= usieron manos a la obra, cada uno construyó su cas ----> i
# Seq( 266 )= sieron manos a la obra, cada uno construyó su casi ----> t
# Seq( 267 )= ieron manos a la obra, cada uno construyó su casit ----> a
# Seq( 268 )= eron manos a la obra, cada uno construyó su casita ----> .
# Seq( 269 )= ron manos a la obra, cada uno construyó su casita. ---->
# Seq( 270 )= on manos a la obra, cada uno construyó su casita.  ---->
# Seq( 271 )= n manos a la obra, cada uno construyó su casita.   ----> -
# Seq( 272 )=  manos a la obra, cada uno construyó su casita.  - ---->
# Seq( 273 )= manos a la obra, cada uno construyó su casita.  -  ----> l
# Seq( 274 )= anos a la obra, cada uno construyó su casita.  - l ----> a
# Seq( 275 )= nos a la obra, cada uno construyó su casita.  - la ---->
# Seq( 276 )= os a la obra, cada uno construyó su casita.  - la  ----> m
# Seq( 277 )= s a la obra, cada uno construyó su casita.  - la m ----> í
# Seq( 278 )=  a la obra, cada uno construyó su casita.  - la mí ----> a
# Seq( 279 )= a la obra, cada uno construyó su casita.  - la mía ---->
# Seq( 280 )=  la obra, cada uno construyó su casita.  - la mía  ----> s
# Seq( 281 )= la obra, cada uno construyó su casita.  - la mía s ----> e
# Seq( 282 )= a obra, cada uno construyó su casita.  - la mía se ----> r
# Seq( 283 )=  obra, cada uno construyó su casita.  - la mía ser ----> á
# Seq( 284 )= obra, cada uno construyó su casita.  - la mía será ---->
# Seq( 285 )= bra, cada uno construyó su casita.  - la mía será  ----> d
# Seq( 286 )= ra, cada uno construyó su casita.  - la mía será d ----> e
# Seq( 287 )= a, cada uno construyó su casita.  - la mía será de ---->
# Seq( 288 )= , cada uno construyó su casita.  - la mía será de  ----> p
# Seq( 289 )=  cada uno construyó su casita.  - la mía será de p ----> a
# Seq( 290 )= cada uno construyó su casita.  - la mía será de pa ----> j
# Seq( 291 )= ada uno construyó su casita.  - la mía será de paj ----> a
# Seq( 292 )= da uno construyó su casita.  - la mía será de paja ---->
# Seq( 293 )= a uno construyó su casita.  - la mía será de paja  ----> -
# Seq( 294 )=  uno construyó su casita.  - la mía será de paja - ---->
# Seq( 295 )= uno construyó su casita.  - la mía será de paja -  ----> d
# Seq( 296 )= no construyó su casita.  - la mía será de paja - d ----> i
# Seq( 297 )= o construyó su casita.  - la mía será de paja - di ----> j
# Seq( 298 )=  construyó su casita.  - la mía será de paja - dij ----> o
# Seq( 299 )= construyó su casita.  - la mía será de paja - dijo ---->
# Seq( 300 )= onstruyó su casita.  - la mía será de paja - dijo  ----> e
# Seq( 301 )= nstruyó su casita.  - la mía será de paja - dijo e ----> l
# Seq( 302 )= struyó su casita.  - la mía será de paja - dijo el ---->
# Seq( 303 )= truyó su casita.  - la mía será de paja - dijo el  ----> m
# Seq( 304 )= ruyó su casita.  - la mía será de paja - dijo el m ----> á
# Seq( 305 )= uyó su casita.  - la mía será de paja - dijo el má ----> s
# Seq( 306 )= yó su casita.  - la mía será de paja - dijo el más ---->
# Seq( 307 )= ó su casita.  - la mía será de paja - dijo el más  ----> p
# Seq( 308 )=  su casita.  - la mía será de paja - dijo el más p ----> e
# Seq( 309 )= su casita.  - la mía será de paja - dijo el más pe ----> q
# Seq( 310 )= u casita.  - la mía será de paja - dijo el más peq ----> u
# Seq( 311 )=  casita.  - la mía será de paja - dijo el más pequ ----> e
# Seq( 312 )= casita.  - la mía será de paja - dijo el más peque ----> ñ
# Seq( 313 )= asita.  - la mía será de paja - dijo el más pequeñ ----> o
# Seq( 314 )= sita.  - la mía será de paja - dijo el más pequeño ----> -
# Seq( 315 )= ita.  - la mía será de paja - dijo el más pequeño- ----> ,
# Seq( 316 )= ta.  - la mía será de paja - dijo el más pequeño-, ---->
# Seq( 317 )= a.  - la mía será de paja - dijo el más pequeño-,  ----> l
# Seq( 318 )= .  - la mía será de paja - dijo el más pequeño-, l ----> a
# Seq( 319 )=   - la mía será de paja - dijo el más pequeño-, la ---->
# Seq( 320 )=  - la mía será de paja - dijo el más pequeño-, la  ----> p
# Seq( 321 )= - la mía será de paja - dijo el más pequeño-, la p ----> a
# Seq( 322 )=  la mía será de paja - dijo el más pequeño-, la pa ----> j
# Seq( 323 )= la mía será de paja - dijo el más pequeño-, la paj ----> a
# Seq( 324 )= a mía será de paja - dijo el más pequeño-, la paja ---->
# Seq( 325 )=  mía será de paja - dijo el más pequeño-, la paja  ----> e
# Seq( 326 )= mía será de paja - dijo el más pequeño-, la paja e ----> s
# Seq( 327 )= ía será de paja - dijo el más pequeño-, la paja es ---->
# Seq( 328 )= a será de paja - dijo el más pequeño-, la paja es  ----> b
# Seq( 329 )=  será de paja - dijo el más pequeño-, la paja es b ----> l
# Seq( 330 )= será de paja - dijo el más pequeño-, la paja es bl ----> a
# Seq( 331 )= erá de paja - dijo el más pequeño-, la paja es bla ----> n
# Seq( 332 )= rá de paja - dijo el más pequeño-, la paja es blan ----> d
# Seq( 333 )= á de paja - dijo el más pequeño-, la paja es bland ----> a
# Seq( 334 )=  de paja - dijo el más pequeño-, la paja es blanda ---->
# Seq( 335 )= de paja - dijo el más pequeño-, la paja es blanda  ----> y
# Seq( 336 )= e paja - dijo el más pequeño-, la paja es blanda y ---->
# Seq( 337 )=  paja - dijo el más pequeño-, la paja es blanda y  ----> s
# Seq( 338 )= paja - dijo el más pequeño-, la paja es blanda y s ----> e
# Seq( 339 )= aja - dijo el más pequeño-, la paja es blanda y se ---->
# Seq( 340 )= ja - dijo el más pequeño-, la paja es blanda y se  ----> p
# Seq( 341 )= a - dijo el más pequeño-, la paja es blanda y se p ----> u
# Seq( 342 )=  - dijo el más pequeño-, la paja es blanda y se pu ----> e
# Seq( 343 )= - dijo el más pequeño-, la paja es blanda y se pue ----> d
# Seq( 344 )=  dijo el más pequeño-, la paja es blanda y se pued ----> e
# Seq( 345 )= dijo el más pequeño-, la paja es blanda y se puede ---->
# Seq( 346 )= ijo el más pequeño-, la paja es blanda y se puede  ----> s
# Seq( 347 )= jo el más pequeño-, la paja es blanda y se puede s ----> u
# Seq( 348 )= o el más pequeño-, la paja es blanda y se puede su ----> j
# Seq( 349 )=  el más pequeño-, la paja es blanda y se puede suj ----> e
# Seq( 350 )= el más pequeño-, la paja es blanda y se puede suje ----> t
# Seq( 351 )= l más pequeño-, la paja es blanda y se puede sujet ----> a
# Seq( 352 )=  más pequeño-, la paja es blanda y se puede sujeta ----> r
# Seq( 353 )= más pequeño-, la paja es blanda y se puede sujetar ---->
# Seq( 354 )= ás pequeño-, la paja es blanda y se puede sujetar  ----> c
# Seq( 355 )= s pequeño-, la paja es blanda y se puede sujetar c ----> o
# Seq( 356 )=  pequeño-, la paja es blanda y se puede sujetar co ----> n
# Seq( 357 )= pequeño-, la paja es blanda y se puede sujetar con ---->
# Seq( 358 )= equeño-, la paja es blanda y se puede sujetar con  ----> f
# Seq( 359 )= queño-, la paja es blanda y se puede sujetar con f ----> a
# Seq( 360 )= ueño-, la paja es blanda y se puede sujetar con fa ----> c
# Seq( 361 )= eño-, la paja es blanda y se puede sujetar con fac ----> i
# Seq( 362 )= ño-, la paja es blanda y se puede sujetar con faci ----> l
# Seq( 363 )= o-, la paja es blanda y se puede sujetar con facil ----> i
# Seq( 364 )= -, la paja es blanda y se puede sujetar con facili ----> d
# Seq( 365 )= , la paja es blanda y se puede sujetar con facilid ----> a
# Seq( 366 )=  la paja es blanda y se puede sujetar con facilida ----> d
# Seq( 367 )= la paja es blanda y se puede sujetar con facilidad ----> .
# Seq( 368 )= a paja es blanda y se puede sujetar con facilidad. ---->
# Seq( 369 )=  paja es blanda y se puede sujetar con facilidad.  ----> t
# Seq( 370 )= paja es blanda y se puede sujetar con facilidad. t ----> e
# Seq( 371 )= aja es blanda y se puede sujetar con facilidad. te ----> r
# Seq( 372 )= ja es blanda y se puede sujetar con facilidad. ter ----> m
# Seq( 373 )= a es blanda y se puede sujetar con facilidad. term ----> i
# Seq( 374 )=  es blanda y se puede sujetar con facilidad. termi ----> n
# Seq( 375 )= es blanda y se puede sujetar con facilidad. termin ----> a
# Seq( 376 )= s blanda y se puede sujetar con facilidad. termina ----> r
# Seq( 377 )=  blanda y se puede sujetar con facilidad. terminar ----> é
# Seq( 378 )= blanda y se puede sujetar con facilidad. terminaré ---->
# Seq( 379 )= landa y se puede sujetar con facilidad. terminaré  ----> m
# Seq( 380 )= anda y se puede sujetar con facilidad. terminaré m ----> u
# Seq( 381 )= nda y se puede sujetar con facilidad. terminaré mu ----> y
# Seq( 382 )= da y se puede sujetar con facilidad. terminaré muy ---->
# Seq( 383 )= a y se puede sujetar con facilidad. terminaré muy  ----> p
# Seq( 384 )=  y se puede sujetar con facilidad. terminaré muy p ----> r
# Seq( 385 )= y se puede sujetar con facilidad. terminaré muy pr ----> o
# Seq( 386 )=  se puede sujetar con facilidad. terminaré muy pro ----> n
# Seq( 387 )= se puede sujetar con facilidad. terminaré muy pron ----> t
# Seq( 388 )= e puede sujetar con facilidad. terminaré muy pront ----> o
# Seq( 389 )=  puede sujetar con facilidad. terminaré muy pronto ---->
# Seq( 390 )= puede sujetar con facilidad. terminaré muy pronto  ----> y
# Seq( 391 )= uede sujetar con facilidad. terminaré muy pronto y ---->
# Seq( 392 )= ede sujetar con facilidad. terminaré muy pronto y  ----> p
# Seq( 393 )= de sujetar con facilidad. terminaré muy pronto y p ----> o
# Seq( 394 )= e sujetar con facilidad. terminaré muy pronto y po ----> d
# Seq( 395 )=  sujetar con facilidad. terminaré muy pronto y pod ----> r
# Seq( 396 )= sujetar con facilidad. terminaré muy pronto y podr ----> é
# Seq( 397 )= ujetar con facilidad. terminaré muy pronto y podré ---->
# Seq( 398 )= jetar con facilidad. terminaré muy pronto y podré  ----> i
# Seq( 399 )= etar con facilidad. terminaré muy pronto y podré i ----> r
# Seq( 400 )= tar con facilidad. terminaré muy pronto y podré ir ---->
# Seq( 401 )= ar con facilidad. terminaré muy pronto y podré ir  ----> a
# Seq( 402 )= r con facilidad. terminaré muy pronto y podré ir a ---->
# Seq( 403 )=  con facilidad. terminaré muy pronto y podré ir a  ----> j
# Seq( 404 )= con facilidad. terminaré muy pronto y podré ir a j ----> u
# Seq( 405 )= on facilidad. terminaré muy pronto y podré ir a ju ----> g
# Seq( 406 )= n facilidad. terminaré muy pronto y podré ir a jug ----> a
# Seq( 407 )=  facilidad. terminaré muy pronto y podré ir a juga ----> r
# Seq( 408 )= facilidad. terminaré muy pronto y podré ir a jugar ----> .
# Seq( 409 )= acilidad. terminaré muy pronto y podré ir a jugar. ---->
# Seq( 410 )= cilidad. terminaré muy pronto y podré ir a jugar.  ----> e
# Seq( 411 )= ilidad. terminaré muy pronto y podré ir a jugar. e ----> l
# Seq( 412 )= lidad. terminaré muy pronto y podré ir a jugar. el ---->
# Seq( 413 )= idad. terminaré muy pronto y podré ir a jugar. el  ----> h
# Seq( 414 )= dad. terminaré muy pronto y podré ir a jugar. el h ----> e
# Seq( 415 )= ad. terminaré muy pronto y podré ir a jugar. el he ----> r
# Seq( 416 )= d. terminaré muy pronto y podré ir a jugar. el her ----> m
# Seq( 417 )= . terminaré muy pronto y podré ir a jugar. el herm ----> a
# Seq( 418 )=  terminaré muy pronto y podré ir a jugar. el herma ----> n
# Seq( 419 )= terminaré muy pronto y podré ir a jugar. el herman ----> o
# Seq( 420 )= erminaré muy pronto y podré ir a jugar. el hermano ---->
# Seq( 421 )= rminaré muy pronto y podré ir a jugar. el hermano  ----> m
# Seq( 422 )= minaré muy pronto y podré ir a jugar. el hermano m ----> e
# Seq( 423 )= inaré muy pronto y podré ir a jugar. el hermano me ----> d
# Seq( 424 )= naré muy pronto y podré ir a jugar. el hermano med ----> i
# Seq( 425 )= aré muy pronto y podré ir a jugar. el hermano medi ----> a
# Seq( 426 )= ré muy pronto y podré ir a jugar. el hermano media ----> n
# Seq( 427 )= é muy pronto y podré ir a jugar. el hermano median ----> o
# Seq( 428 )=  muy pronto y podré ir a jugar. el hermano mediano ---->
# Seq( 429 )= muy pronto y podré ir a jugar. el hermano mediano  ----> d
# Seq( 430 )= uy pronto y podré ir a jugar. el hermano mediano d ----> e
# Seq( 431 )= y pronto y podré ir a jugar. el hermano mediano de ----> c
# Seq( 432 )=  pronto y podré ir a jugar. el hermano mediano dec ----> i
# Seq( 433 )= pronto y podré ir a jugar. el hermano mediano deci ----> d
# Seq( 434 )= ronto y podré ir a jugar. el hermano mediano decid ----> i
# Seq( 435 )= onto y podré ir a jugar. el hermano mediano decidi ----> ó
# Seq( 436 )= nto y podré ir a jugar. el hermano mediano decidió ---->
# Seq( 437 )= to y podré ir a jugar. el hermano mediano decidió  ----> q
# Seq( 438 )= o y podré ir a jugar. el hermano mediano decidió q ----> u
# Seq( 439 )=  y podré ir a jugar. el hermano mediano decidió qu ----> e
# Seq( 440 )= y podré ir a jugar. el hermano mediano decidió que ---->
# Seq( 441 )=  podré ir a jugar. el hermano mediano decidió que  ----> s
# Seq( 442 )= podré ir a jugar. el hermano mediano decidió que s ----> u
# Seq( 443 )= odré ir a jugar. el hermano mediano decidió que su ---->
# Seq( 444 )= dré ir a jugar. el hermano mediano decidió que su  ----> c
# Seq( 445 )= ré ir a jugar. el hermano mediano decidió que su c ----> a
# Seq( 446 )= é ir a jugar. el hermano mediano decidió que su ca ----> s
# Seq( 447 )=  ir a jugar. el hermano mediano decidió que su cas ----> a
# Seq( 448 )= ir a jugar. el hermano mediano decidió que su casa ---->
# Seq( 449 )= r a jugar. el hermano mediano decidió que su casa  ----> s
# Seq( 450 )=  a jugar. el hermano mediano decidió que su casa s ----> e
# Seq( 451 )= a jugar. el hermano mediano decidió que su casa se ----> r
# Seq( 452 )=  jugar. el hermano mediano decidió que su casa ser ----> í
# Seq( 453 )= jugar. el hermano mediano decidió que su casa serí ----> a
# Seq( 454 )= ugar. el hermano mediano decidió que su casa sería ---->
# Seq( 455 )= gar. el hermano mediano decidió que su casa sería  ----> d
# Seq( 456 )= ar. el hermano mediano decidió que su casa sería d ----> e
# Seq( 457 )= r. el hermano mediano decidió que su casa sería de ---->
# Seq( 458 )= . el hermano mediano decidió que su casa sería de  ----> m
# Seq( 459 )=  el hermano mediano decidió que su casa sería de m ----> a
# Seq( 460 )= el hermano mediano decidió que su casa sería de ma ----> d
# Seq( 461 )= l hermano mediano decidió que su casa sería de mad ----> e
# Seq( 462 )=  hermano mediano decidió que su casa sería de made ----> r
# Seq( 463 )= hermano mediano decidió que su casa sería de mader ----> a
# Seq( 464 )= ermano mediano decidió que su casa sería de madera ----> :
# Seq( 465 )= rmano mediano decidió que su casa sería de madera: ---->
# Seq( 466 )= mano mediano decidió que su casa sería de madera:  ---->
# Seq( 467 )= ano mediano decidió que su casa sería de madera:   ----> -
# Seq( 468 )= no mediano decidió que su casa sería de madera:  - ---->
# Seq( 469 )= o mediano decidió que su casa sería de madera:  -  ----> p
# Seq( 470 )=  mediano decidió que su casa sería de madera:  - p ----> u
# Seq( 471 )= mediano decidió que su casa sería de madera:  - pu ----> e
# Seq( 472 )= ediano decidió que su casa sería de madera:  - pue ----> d
# Seq( 473 )= diano decidió que su casa sería de madera:  - pued ----> o
# Seq( 474 )= iano decidió que su casa sería de madera:  - puedo ---->
# Seq( 475 )= ano decidió que su casa sería de madera:  - puedo  ----> e
# Seq( 476 )= no decidió que su casa sería de madera:  - puedo e ----> n
# Seq( 477 )= o decidió que su casa sería de madera:  - puedo en ----> c
# Seq( 478 )=  decidió que su casa sería de madera:  - puedo enc ----> o
# Seq( 479 )= decidió que su casa sería de madera:  - puedo enco ----> n
# Seq( 480 )= ecidió que su casa sería de madera:  - puedo encon ----> t
# Seq( 481 )= cidió que su casa sería de madera:  - puedo encont ----> r
# Seq( 482 )= idió que su casa sería de madera:  - puedo encontr ----> a
# Seq( 483 )= dió que su casa sería de madera:  - puedo encontra ----> r
# Seq( 484 )= ió que su casa sería de madera:  - puedo encontrar ---->
# Seq( 485 )= ó que su casa sería de madera:  - puedo encontrar  ----> u
# Seq( 486 )=  que su casa sería de madera:  - puedo encontrar u ----> n
# Seq( 487 )= que su casa sería de madera:  - puedo encontrar un ---->
# Seq( 488 )= ue su casa sería de madera:  - puedo encontrar un  ----> m
# Seq( 489 )= e su casa sería de madera:  - puedo encontrar un m ----> o
# Seq( 490 )=  su casa sería de madera:  - puedo encontrar un mo ----> n
# Seq( 491 )= su casa sería de madera:  - puedo encontrar un mon ----> t
# Seq( 492 )= u casa sería de madera:  - puedo encontrar un mont ----> ó
# Seq( 493 )=  casa sería de madera:  - puedo encontrar un montó ----> n
# Seq( 494 )= casa sería de madera:  - puedo encontrar un montón ---->
# Seq( 495 )= asa sería de madera:  - puedo encontrar un montón  ----> d
# Seq( 496 )= sa sería de madera:  - puedo encontrar un montón d ----> e
# Seq( 497 )= a sería de madera:  - puedo encontrar un montón de ---->
# Seq( 498 )=  sería de madera:  - puedo encontrar un montón de  ----> m
# Seq( 499 )= sería de madera:  - puedo encontrar un montón de m ----> a
# Seq( 500 )= ería de madera:  - puedo encontrar un montón de ma ----> d
# Seq( 501 )= ría de madera:  - puedo encontrar un montón de mad ----> e
# Seq( 502 )= ía de madera:  - puedo encontrar un montón de made ----> r
# Seq( 503 )= a de madera:  - puedo encontrar un montón de mader ----> a
# Seq( 504 )=  de madera:  - puedo encontrar un montón de madera ---->
# Seq( 505 )= de madera:  - puedo encontrar un montón de madera  ----> p
# Seq( 506 )= e madera:  - puedo encontrar un montón de madera p ----> o
# Seq( 507 )=  madera:  - puedo encontrar un montón de madera po ----> r
# Seq( 508 )= madera:  - puedo encontrar un montón de madera por ---->
# Seq( 509 )= adera:  - puedo encontrar un montón de madera por  ----> l
# Seq( 510 )= dera:  - puedo encontrar un montón de madera por l ----> o
# Seq( 511 )= era:  - puedo encontrar un montón de madera por lo ----> s
# Seq( 512 )= ra:  - puedo encontrar un montón de madera por los ---->
# Seq( 513 )= a:  - puedo encontrar un montón de madera por los  ----> a
# Seq( 514 )= :  - puedo encontrar un montón de madera por los a ----> l
# Seq( 515 )=   - puedo encontrar un montón de madera por los al ----> r
# Seq( 516 )=  - puedo encontrar un montón de madera por los alr ----> e
# Seq( 517 )= - puedo encontrar un montón de madera por los alre ----> d
# Seq( 518 )=  puedo encontrar un montón de madera por los alred ----> e
# Seq( 519 )= puedo encontrar un montón de madera por los alrede ----> d
# Seq( 520 )= uedo encontrar un montón de madera por los alreded ----> o
# Seq( 521 )= edo encontrar un montón de madera por los alrededo ----> r
# Seq( 522 )= do encontrar un montón de madera por los alrededor ----> e
# Seq( 523 )= o encontrar un montón de madera por los alrededore ----> s
# Seq( 524 )=  encontrar un montón de madera por los alrededores ---->
# Seq( 525 )= encontrar un montón de madera por los alrededores  ----> -
# Seq( 526 )= ncontrar un montón de madera por los alrededores - ---->
# Seq( 527 )= contrar un montón de madera por los alrededores -  ----> e
# Seq( 528 )= ontrar un montón de madera por los alrededores - e ----> x
# Seq( 529 )= ntrar un montón de madera por los alrededores - ex ----> p
# Seq( 530 )= trar un montón de madera por los alrededores - exp ----> l
# Seq( 531 )= rar un montón de madera por los alrededores - expl ----> i
# Seq( 532 )= ar un montón de madera por los alrededores - expli ----> c
# Seq( 533 )= r un montón de madera por los alrededores - explic ----> ó
# Seq( 534 )=  un montón de madera por los alrededores - explicó ---->
# Seq( 535 )= un montón de madera por los alrededores - explicó  ---->
#  ---->
#
# Seq( 537 )=  montón de madera por los alrededores - explicó
#  ----> a
# Seq( 538 )= montón de madera por los alrededores - explicó
# a ---->
# Seq( 539 )= ontón de madera por los alrededores - explicó
# a  ----> s
# Seq( 540 )= ntón de madera por los alrededores - explicó
# a s ----> u
# Seq( 541 )= tón de madera por los alrededores - explicó
# a su ----> s
# Seq( 542 )= ón de madera por los alrededores - explicó
# a sus ---->
# Seq( 543 )= n de madera por los alrededores - explicó
# a sus  ----> h
# Seq( 544 )=  de madera por los alrededores - explicó
# a sus h ----> e
# Seq( 545 )= de madera por los alrededores - explicó
# a sus he ----> r
# Seq( 546 )= e madera por los alrededores - explicó
# a sus her ----> m
# Seq( 547 )=  madera por los alrededores - explicó
# a sus herm ----> a
# Seq( 548 )= madera por los alrededores - explicó
# a sus herma ----> n
# Seq( 549 )= adera por los alrededores - explicó
# a sus herman ----> o
# Seq( 550 )= dera por los alrededores - explicó
# a sus hermano ----> s
# Seq( 551 )= era por los alrededores - explicó
# a sus hermanos ----> ,
# Seq( 552 )= ra por los alrededores - explicó
# a sus hermanos, ---->
# Seq( 553 )= a por los alrededores - explicó
# a sus hermanos,  ----> -
# Seq( 554 )=  por los alrededores - explicó
# a sus hermanos, - ---->
# Seq( 555 )= por los alrededores - explicó
# a sus hermanos, -  ----> c
# Seq( 556 )= or los alrededores - explicó
# a sus hermanos, - c ----> o
# Seq( 557 )= r los alrededores - explicó
# a sus hermanos, - co ----> n
# Seq( 558 )=  los alrededores - explicó
# a sus hermanos, - con ----> s
# Seq( 559 )= los alrededores - explicó
# a sus hermanos, - cons ----> t
# Seq( 560 )= os alrededores - explicó
# a sus hermanos, - const ----> r
# Seq( 561 )= s alrededores - explicó
# a sus hermanos, - constr ----> u
# Seq( 562 )=  alrededores - explicó
# a sus hermanos, - constru ----> i
# Seq( 563 )= alrededores - explicó
# a sus hermanos, - construi ----> r
# Seq( 564 )= lrededores - explicó
# a sus hermanos, - construir ----> é
# Seq( 565 )= rededores - explicó
# a sus hermanos, - construiré ---->
# Seq( 566 )= ededores - explicó
# a sus hermanos, - construiré  ----> m
# Seq( 567 )= dedores - explicó
# a sus hermanos, - construiré m ----> i
# Seq( 568 )= edores - explicó
# a sus hermanos, - construiré mi ---->
# Seq( 569 )= dores - explicó
# a sus hermanos, - construiré mi  ----> c
# Seq( 570 )= ores - explicó
# a sus hermanos, - construiré mi c ----> a
# Seq( 571 )= res - explicó
# a sus hermanos, - construiré mi ca ----> s
# Seq( 572 )= es - explicó
# a sus hermanos, - construiré mi cas ----> a
# Seq( 573 )= s - explicó
# a sus hermanos, - construiré mi casa ---->
# Seq( 574 )=  - explicó
# a sus hermanos, - construiré mi casa  ----> e
# Seq( 575 )= - explicó
# a sus hermanos, - construiré mi casa e ----> n
# Seq( 576 )=  explicó
# a sus hermanos, - construiré mi casa en ---->
# Seq( 577 )= explicó
# a sus hermanos, - construiré mi casa en  ----> u
# Seq( 578 )= xplicó
# a sus hermanos, - construiré mi casa en u ----> n
# Seq( 579 )= plicó
# a sus hermanos, - construiré mi casa en un ---->
# Seq( 580 )= licó
# a sus hermanos, - construiré mi casa en un  ----> s
# Seq( 581 )= icó
# a sus hermanos, - construiré mi casa en un s ----> a
# Seq( 582 )= có
# a sus hermanos, - construiré mi casa en un sa ----> n
# Seq( 583 )= ó
# a sus hermanos, - construiré mi casa en un san ----> t
# Seq( 584 )=
# a sus hermanos, - construiré mi casa en un sant ----> i
# Seq( 585 )=
# a sus hermanos, - construiré mi casa en un santi ----> a
# Seq( 586 )=
# a sus hermanos, - construiré mi casa en un santia ----> m
# Seq( 587 )= a sus hermanos, - construiré mi casa en un santiam ----> é
# Seq( 588 )=  sus hermanos, - construiré mi casa en un santiamé ----> n
# Seq( 589 )= sus hermanos, - construiré mi casa en un santiamén ---->
# Seq( 590 )= us hermanos, - construiré mi casa en un santiamén  ----> c
# Seq( 591 )= s hermanos, - construiré mi casa en un santiamén c ----> o
# Seq( 592 )=  hermanos, - construiré mi casa en un santiamén co ----> n
# Seq( 593 )= hermanos, - construiré mi casa en un santiamén con ---->
# Seq( 594 )= ermanos, - construiré mi casa en un santiamén con  ----> t
# Seq( 595 )= rmanos, - construiré mi casa en un santiamén con t ----> o
# Seq( 596 )= manos, - construiré mi casa en un santiamén con to ----> d
# Seq( 597 )= anos, - construiré mi casa en un santiamén con tod ----> o
# Seq( 598 )= nos, - construiré mi casa en un santiamén con todo ----> s
# Seq( 599 )= os, - construiré mi casa en un santiamén con todos ---->
# Seq( 600 )= s, - construiré mi casa en un santiamén con todos  ----> e
# Seq( 601 )= , - construiré mi casa en un santiamén con todos e ----> s
# Seq( 602 )=  - construiré mi casa en un santiamén con todos es ----> t
# Seq( 603 )= - construiré mi casa en un santiamén con todos est ----> o
# Seq( 604 )=  construiré mi casa en un santiamén con todos esto ----> s
# Seq( 605 )= construiré mi casa en un santiamén con todos estos ---->
# Seq( 606 )= onstruiré mi casa en un santiamén con todos estos  ----> t
# Seq( 607 )= nstruiré mi casa en un santiamén con todos estos t ----> r
# Seq( 608 )= struiré mi casa en un santiamén con todos estos tr ----> o
# Seq( 609 )= truiré mi casa en un santiamén con todos estos tro ----> n
# Seq( 610 )= ruiré mi casa en un santiamén con todos estos tron ----> c
# Seq( 611 )= uiré mi casa en un santiamén con todos estos tronc ----> o
# Seq( 612 )= iré mi casa en un santiamén con todos estos tronco ----> s
# Seq( 613 )= ré mi casa en un santiamén con todos estos troncos ---->
# Seq( 614 )= é mi casa en un santiamén con todos estos troncos  ----> y
# Seq( 615 )=  mi casa en un santiamén con todos estos troncos y ---->
# Seq( 616 )= mi casa en un santiamén con todos estos troncos y  ----> m
# Seq( 617 )= i casa en un santiamén con todos estos troncos y m ----> e
# Seq( 618 )=  casa en un santiamén con todos estos troncos y me ---->
# Seq( 619 )= casa en un santiamén con todos estos troncos y me  ----> i
# Seq( 620 )= asa en un santiamén con todos estos troncos y me i ----> r
# Seq( 621 )= sa en un santiamén con todos estos troncos y me ir ----> é
# Seq( 622 )= a en un santiamén con todos estos troncos y me iré ---->
# Seq( 623 )=  en un santiamén con todos estos troncos y me iré  ----> t
# Seq( 624 )= en un santiamén con todos estos troncos y me iré t ----> a
# Seq( 625 )= n un santiamén con todos estos troncos y me iré ta ----> m
# Seq( 626 )=  un santiamén con todos estos troncos y me iré tam ----> b
# Seq( 627 )= un santiamén con todos estos troncos y me iré tamb ----> i
# Seq( 628 )= n santiamén con todos estos troncos y me iré tambi ----> é
# Seq( 629 )=  santiamén con todos estos troncos y me iré tambié ----> n
# Seq( 630 )= santiamén con todos estos troncos y me iré también ---->
# Seq( 631 )= antiamén con todos estos troncos y me iré también  ----> a
# Seq( 632 )= ntiamén con todos estos troncos y me iré también a ---->
# Seq( 633 )= tiamén con todos estos troncos y me iré también a  ----> j
# Seq( 634 )= iamén con todos estos troncos y me iré también a j ----> u
# Seq( 635 )= amén con todos estos troncos y me iré también a ju ----> g
# Seq( 636 )= mén con todos estos troncos y me iré también a jug ----> a
# Seq( 637 )= én con todos estos troncos y me iré también a juga ----> r
# Seq( 638 )= n con todos estos troncos y me iré también a jugar ----> .
# Seq( 639 )=  con todos estos troncos y me iré también a jugar. ---->
# Seq( 640 )= con todos estos troncos y me iré también a jugar.  ---->
# Seq( 641 )= on todos estos troncos y me iré también a jugar.   ----> c
# Seq( 642 )= n todos estos troncos y me iré también a jugar.  c ----> u
# Seq( 643 )=  todos estos troncos y me iré también a jugar.  cu ----> a
# Seq( 644 )= todos estos troncos y me iré también a jugar.  cua ----> n
# Seq( 645 )= odos estos troncos y me iré también a jugar.  cuan ----> d
# Seq( 646 )= dos estos troncos y me iré también a jugar.  cuand ----> o
# Seq( 647 )= os estos troncos y me iré también a jugar.  cuando ---->
# Seq( 648 )= s estos troncos y me iré también a jugar.  cuando  ----> l
# Seq( 649 )=  estos troncos y me iré también a jugar.  cuando l ----> a
# Seq( 650 )= estos troncos y me iré también a jugar.  cuando la ----> s
# Seq( 651 )= stos troncos y me iré también a jugar.  cuando las ---->
# Seq( 652 )= tos troncos y me iré también a jugar.  cuando las  ----> t
# Seq( 653 )= os troncos y me iré también a jugar.  cuando las t ----> r
# Seq( 654 )= s troncos y me iré también a jugar.  cuando las tr ----> e
# Seq( 655 )=  troncos y me iré también a jugar.  cuando las tre ----> s
# Seq( 656 )= troncos y me iré también a jugar.  cuando las tres ---->
# Seq( 657 )= roncos y me iré también a jugar.  cuando las tres  ----> c
# Seq( 658 )= oncos y me iré también a jugar.  cuando las tres c ----> a
# Seq( 659 )= ncos y me iré también a jugar.  cuando las tres ca ----> s
# Seq( 660 )= cos y me iré también a jugar.  cuando las tres cas ----> i
# Seq( 661 )= os y me iré también a jugar.  cuando las tres casi ----> t
# Seq( 662 )= s y me iré también a jugar.  cuando las tres casit ----> a
# Seq( 663 )=  y me iré también a jugar.  cuando las tres casita ----> s
# Seq( 664 )= y me iré también a jugar.  cuando las tres casitas ---->
# Seq( 665 )=  me iré también a jugar.  cuando las tres casitas  ----> e
# Seq( 666 )= me iré también a jugar.  cuando las tres casitas e ----> s
# Seq( 667 )= e iré también a jugar.  cuando las tres casitas es ----> t
# Seq( 668 )=  iré también a jugar.  cuando las tres casitas est ----> u
# Seq( 669 )= iré también a jugar.  cuando las tres casitas estu ----> v
# Seq( 670 )= ré también a jugar.  cuando las tres casitas estuv ----> i
# Seq( 671 )= é también a jugar.  cuando las tres casitas estuvi ----> e
# Seq( 672 )=  también a jugar.  cuando las tres casitas estuvie ----> r
# Seq( 673 )= también a jugar.  cuando las tres casitas estuvier ----> o
# Seq( 674 )= ambién a jugar.  cuando las tres casitas estuviero ----> n
# Seq( 675 )= mbién a jugar.  cuando las tres casitas estuvieron ---->
# Seq( 676 )= bién a jugar.  cuando las tres casitas estuvieron  ----> t
# Seq( 677 )= ién a jugar.  cuando las tres casitas estuvieron t ----> e
# Seq( 678 )= én a jugar.  cuando las tres casitas estuvieron te ----> r
# ...
# Seq( 2983 )= erdos, sabréis que son los tres cerditos porque le ----> s
# Seq( 2984 )= rdos, sabréis que son los tres cerditos porque les ---->
# Seq( 2985 )= dos, sabréis que son los tres cerditos porque les  ----> g
# Seq( 2986 )= os, sabréis que son los tres cerditos porque les g ----> u
# Seq( 2987 )= s, sabréis que son los tres cerditos porque les gu ----> s
# Seq( 2988 )= , sabréis que son los tres cerditos porque les gus ----> t
# Seq( 2989 )=  sabréis que son los tres cerditos porque les gust ----> a
# Seq( 2990 )= sabréis que son los tres cerditos porque les gusta ---->
# Seq( 2991 )= abréis que son los tres cerditos porque les gusta  ----> c
# Seq( 2992 )= bréis que son los tres cerditos porque les gusta c ----> a
# Seq( 2993 )= réis que son los tres cerditos porque les gusta ca ----> n
# Seq( 2994 )= éis que son los tres cerditos porque les gusta can ----> t
# Seq( 2995 )= is que son los tres cerditos porque les gusta cant ----> a
# Seq( 2996 )= s que son los tres cerditos porque les gusta canta ----> r
# Seq( 2997 )=  que son los tres cerditos porque les gusta cantar ----> :
# Seq( 2998 )= que son los tres cerditos porque les gusta cantar: ---->
# Seq( 2999 )= ue son los tres cerditos porque les gusta cantar:  ---->
# Seq( 3000 )= e son los tres cerditos porque les gusta cantar:   ----> -
# Seq( 3001 )=  son los tres cerditos porque les gusta cantar:  - ---->
# Seq( 3002 )= son los tres cerditos porque les gusta cantar:  -  ----> ¡
# Seq( 3003 )= on los tres cerditos porque les gusta cantar:  - ¡ ----> q
# Seq( 3004 )= n los tres cerditos porque les gusta cantar:  - ¡q ----> u
# Seq( 3005 )=  los tres cerditos porque les gusta cantar:  - ¡qu ----> i
# Seq( 3006 )= los tres cerditos porque les gusta cantar:  - ¡qui ----> é
# Seq( 3007 )= os tres cerditos porque les gusta cantar:  - ¡quié ----> n
# Seq( 3008 )= s tres cerditos porque les gusta cantar:  - ¡quién ---->
# Seq( 3009 )=  tres cerditos porque les gusta cantar:  - ¡quién  ----> t
# Seq( 3010 )= tres cerditos porque les gusta cantar:  - ¡quién t ----> e
# Seq( 3011 )= res cerditos porque les gusta cantar:  - ¡quién te ----> m
# Seq( 3012 )= es cerditos porque les gusta cantar:  - ¡quién tem ----> e
# Seq( 3013 )= s cerditos porque les gusta cantar:  - ¡quién teme ---->
# Seq( 3014 )=  cerditos porque les gusta cantar:  - ¡quién teme  ----> a
# Seq( 3015 )= cerditos porque les gusta cantar:  - ¡quién teme a ----> l
# Seq( 3016 )= erditos porque les gusta cantar:  - ¡quién teme al ---->
# Seq( 3017 )= rditos porque les gusta cantar:  - ¡quién teme al  ----> l
# Seq( 3018 )= ditos porque les gusta cantar:  - ¡quién teme al l ----> o
# Seq( 3019 )= itos porque les gusta cantar:  - ¡quién teme al lo ----> b
# Seq( 3020 )= tos porque les gusta cantar:  - ¡quién teme al lob ----> o
# Seq( 3021 )= os porque les gusta cantar:  - ¡quién teme al lobo ---->
# Seq( 3022 )= s porque les gusta cantar:  - ¡quién teme al lobo  ----> f
# Seq( 3023 )=  porque les gusta cantar:  - ¡quién teme al lobo f ----> e
# Seq( 3024 )= porque les gusta cantar:  - ¡quién teme al lobo fe ----> r
# Seq( 3025 )= orque les gusta cantar:  - ¡quién teme al lobo fer ----> o
# Seq( 3026 )= rque les gusta cantar:  - ¡quién teme al lobo fero ----> z
# Seq( 3027 )= que les gusta cantar:  - ¡quién teme al lobo feroz ----> ,
# Seq( 3028 )= ue les gusta cantar:  - ¡quién teme al lobo feroz, ---->
# Seq( 3029 )= e les gusta cantar:  - ¡quién teme al lobo feroz,  ----> a
# Seq( 3030 )=  les gusta cantar:  - ¡quién teme al lobo feroz, a ----> l
# Seq( 3031 )= les gusta cantar:  - ¡quién teme al lobo feroz, al ---->
# Seq( 3032 )= es gusta cantar:  - ¡quién teme al lobo feroz, al  ----> l
# Seq( 3033 )= s gusta cantar:  - ¡quién teme al lobo feroz, al l ----> o
# Seq( 3034 )=  gusta cantar:  - ¡quién teme al lobo feroz, al lo ----> b
# Seq( 3035 )= gusta cantar:  - ¡quién teme al lobo feroz, al lob ----> o
# Seq( 3036 )= usta cantar:  - ¡quién teme al lobo feroz, al lobo ----> ,
# Seq( 3037 )= sta cantar:  - ¡quién teme al lobo feroz, al lobo, ---->
# Seq( 3038 )= ta cantar:  - ¡quién teme al lobo feroz, al lobo,  ----> a
# Seq( 3039 )= a cantar:  - ¡quién teme al lobo feroz, al lobo, a ----> l
# Seq( 3040 )=  cantar:  - ¡quién teme al lobo feroz, al lobo, al ---->
# Seq( 3041 )= cantar:  - ¡quién teme al lobo feroz, al lobo, al  ----> l
# Seq( 3042 )= antar:  - ¡quién teme al lobo feroz, al lobo, al l ----> o
# Seq( 3043 )= ntar:  - ¡quién teme al lobo feroz, al lobo, al lo ----> b
# Seq( 3044 )= tar:  - ¡quién teme al lobo feroz, al lobo, al lob ----> o
# Seq( 3045 )= ar:  - ¡quién teme al lobo feroz, al lobo, al lobo ----> !
# Seq( 3046 )= r:  - ¡quién teme al lobo feroz, al lobo, al lobo! ---->
# Seq( 3047 )= :  - ¡quién teme al lobo feroz, al lobo, al lobo!  ---->
# Seq( 3048 )=   - ¡quién teme al lobo feroz, al lobo, al lobo!   ----> -
# Seq( 3049 )=  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ---->
# Seq( 3050 )= - ¡quién teme al lobo feroz, al lobo, al lobo!  -  ----> ¡
# Seq( 3051 )=  ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡ ----> q
# Seq( 3052 )= ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡q ----> u
# Seq( 3053 )= quién teme al lobo feroz, al lobo, al lobo!  - ¡qu ----> i
# Seq( 3054 )= uién teme al lobo feroz, al lobo, al lobo!  - ¡qui ----> é
# Seq( 3055 )= ién teme al lobo feroz, al lobo, al lobo!  - ¡quié ----> n
# Seq( 3056 )= én teme al lobo feroz, al lobo, al lobo!  - ¡quién ---->
# Seq( 3057 )= n teme al lobo feroz, al lobo, al lobo!  - ¡quién  ----> t
# Seq( 3058 )=  teme al lobo feroz, al lobo, al lobo!  - ¡quién t ----> e
# Seq( 3059 )= teme al lobo feroz, al lobo, al lobo!  - ¡quién te ----> m
# Seq( 3060 )= eme al lobo feroz, al lobo, al lobo!  - ¡quién tem ----> e
# Seq( 3061 )= me al lobo feroz, al lobo, al lobo!  - ¡quién teme ---->
# Seq( 3062 )= e al lobo feroz, al lobo, al lobo!  - ¡quién teme  ----> a
# Seq( 3063 )=  al lobo feroz, al lobo, al lobo!  - ¡quién teme a ----> l
# Seq( 3064 )= al lobo feroz, al lobo, al lobo!  - ¡quién teme al ---->
# Seq( 3065 )= l lobo feroz, al lobo, al lobo!  - ¡quién teme al  ----> l
# Seq( 3066 )=  lobo feroz, al lobo, al lobo!  - ¡quién teme al l ----> o
# Seq( 3067 )= lobo feroz, al lobo, al lobo!  - ¡quién teme al lo ----> b
# Seq( 3068 )= obo feroz, al lobo, al lobo!  - ¡quién teme al lob ----> o
# Seq( 3069 )= bo feroz, al lobo, al lobo!  - ¡quién teme al lobo ---->
# Seq( 3070 )= o feroz, al lobo, al lobo!  - ¡quién teme al lobo  ----> f
# Seq( 3071 )=  feroz, al lobo, al lobo!  - ¡quién teme al lobo f ----> e
# Seq( 3072 )= feroz, al lobo, al lobo!  - ¡quién teme al lobo fe ----> r
# Seq( 3073 )= eroz, al lobo, al lobo!  - ¡quién teme al lobo fer ----> o
# Seq( 3074 )= roz, al lobo, al lobo!  - ¡quién teme al lobo fero ----> z
# Seq( 3075 )= oz, al lobo, al lobo!  - ¡quién teme al lobo feroz ----> ,
# Seq( 3076 )= z, al lobo, al lobo!  - ¡quién teme al lobo feroz, ---->
# Seq( 3077 )= , al lobo, al lobo!  - ¡quién teme al lobo feroz,  ----> a
# Seq( 3078 )=  al lobo, al lobo!  - ¡quién teme al lobo feroz, a ----> l
# Seq( 3079 )= al lobo, al lobo!  - ¡quién teme al lobo feroz, al ---->
# Seq( 3080 )= l lobo, al lobo!  - ¡quién teme al lobo feroz, al  ----> l
# Seq( 3081 )=  lobo, al lobo!  - ¡quién teme al lobo feroz, al l ----> o
# Seq( 3082 )= lobo, al lobo!  - ¡quién teme al lobo feroz, al lo ----> b
# Seq( 3083 )= obo, al lobo!  - ¡quién teme al lobo feroz, al lob ----> o
# Seq( 3084 )= bo, al lobo!  - ¡quién teme al lobo feroz, al lobo ---->
# Seq( 3085 )= o, al lobo!  - ¡quién teme al lobo feroz, al lobo  ----> f
# Seq( 3086 )= , al lobo!  - ¡quién teme al lobo feroz, al lobo f ----> e
# Seq( 3087 )=  al lobo!  - ¡quién teme al lobo feroz, al lobo fe ----> r
# Seq( 3088 )= al lobo!  - ¡quién teme al lobo feroz, al lobo fer ----> o
# Seq( 3089 )= l lobo!  - ¡quién teme al lobo feroz, al lobo fero ----> z
# Seq( 3090 )=  lobo!  - ¡quién teme al lobo feroz, al lobo feroz ----> !
# Se generaron  3091  secuencias texto de un tamaño de  50  caracteres
# Como se ven los datos de X convertidos a números
#
# [[15, 8, 9, 35, 8, 2, 27, 20, 8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12], [8, 9, 35, 8, 2, 27, 20, 8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2], [9, 35, 8, 2, 27, 20, 8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13], [35, 8, 2, 27, 20, 8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27], [8, 2, 27, 20, 8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12], [2, 27, 20, 8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24], [27, 20, 8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21], [20, 8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20], [8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2], [2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22], [28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21], [12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24], [31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2], [2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2, 12], [26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2, 12, 18], [24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2, 12, 18, 2], [12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2, 12, 18, 2, 19], [25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2, 12, 18, 2, 19, 27], [2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2, 12, 18, 2, 19, 27, 20], [10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2, 12, 18, 2, 19, 27, 20, 11], [12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2, 12, 18, 2, 19, 27, 20, 11, 21], [24, 11, 16, 26, 21, ...
#
# Como se ven los datos de Y convertidos a números
#
# [2, 13, 27, 12, 24, 21, 20, 2, 22, 21, 24, 2, 12, 18, 2, 19, 27, 20, 11, 21, 2, 8, 2, 10, 21, 20, 25, 12, 14, 27, 16, 24, 2, 13, 21, 24, 26, 27, 20, 8, 6, 2, 12, 18, 2, 19, 33, 25, 2, 14, 24, 8, 20, 11, 12, 2, 18, 12, 25, 2, 11, 16, 17, 21, 2, 8, 2, 25, 27, 25, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 23, 27, 12, 2, 25, 12, 24, 35, 8, 2, 9, 27, 12, 20, 21, 2, 23, 27, 12, 2, 25, 12, 2, 22, 27, 25, 16, 12, 24, 8, 20, 2, 8, 2, 10, 21, 20, 25, 26, 24, 27, 16, 24, 2, 25, 27, 25, 2, 22, 24, 21, 22, 16, 8, 25, 2, 10, 8, 25, 8, 25, 2, 22, 8, 24, 8, 2, 12, 25, 26, 8, 24, 2, 22, 24, 21, 26, 12, 14, 16, 11, 21, 25, 6, 2, 8, 2, 18, 21, 25, 2, 21, 26, 24, 21, 25, 2, 11, 21, 25, 2, 18, 12, 25, 2, 22, 8, 24, 12, 10, 16, 37, 2, 27, 20, 8, 2, 9, 27, 12, 20, 8, 2, 16, 11, 12, 8, 4, 2, 30, 2, 25, 12, 2, 22, 27, 25, 16, 12, 24, 21, 20, 2, 19, 8, 20, 21, 25, 2, 8, 2, 18, 8, 2, 21, 9, 24, 8, 4, 2, 10, 8, 11, 8, 2, 27, 20, 21, 2, 10, 21, 20, 25, 26, 24, 27, 30, 37, 2, 25, 27, 2, 10, 8, 25, 16, 26, 8, 6, 2, 2, 5, 2, 18, 8, 2, 19, 35, 8, 2, 25, 12, 24, 33, 2, 11, 12, 2, 22, 8, 17, 8, 2, 5, 2, 11, 16, 17, 21, 2, 12, 18, 2, 19, 33, 25, 2, 22, 12, 23, 27, 12, 36, 21, 5, 4, 2, 18, 8, 2, 22, 8, 17, 8, 2, 12, 25, 2, 9, 18, 8, 20, 11, 8, 2, 30, 2, 25, 12, 2, 22, 27, 12, 11, 12, 2, 25, 27, 17, 12, 26, 8, 24, 2, 10, 21, 20, 2, 13, 8, 10, 16, 18, 16, 11, 8, 11, 6, 2, 26, 12, 24, 19, 16, 20, 8, 24, 34, 2, 19, 27, 30, 2, 22, 24, 21, 20, 26, 21, 2, 30, 2, 22, 21, 11, 24, 34, 2, 16, 24, 2, 8, 2, 17, 27, 14, 8, 24, 6, 2, 12, 18, 2, 15, 12, 24, 19, 8, 20, 21, 2, 19, 12, 11, 16, 8, 20, 21, 2, 11, 12, 10, 16, 11, 16, 37, 2, 23, 27, 12, 2, 25, 27, 2, 10, 8, 25, 8, 2, 25, 12, 24, 35, 8, 2, 11, 12, 2, 19, 8, 11, 12, 24, 8, 7, 2, 2, 5, 2, 22, 27, 12, 11, 21, 2, 12, 20, 10, 21, 20, 26, 24, 8, 24, 2, 27, 20, 2, 19, 21, 20, 26, 37, 20, 2, 11, 12, 2, 19, 8, 11, 12, 24, 8, 2, 22, 21, 24, 2, 18, 21, 25, 2, 8, 18, 24, 12, 11, 12, 11, 21, 24, 12, 25, 2, 5, 2, 12, 29, 22, 18, 16, 10, 37, 2, 1, 0, 8, 2, 25, 27, 25, 2, 15, 12, 24, 19, 8, 20, 21, 25, 4, 2, 5, 2, 10, 21, 20, 25, 26, 24, 27, 16, 24, 34, 2, 19, 16, 2, 10, 8, 25, 8, 2, 12, 20, 2, 27, 20, 2, 25, 8, 20, 26, 16, 8, 19, 34, 20, 2, 10, 21, 20, 2, 26, 21, 11, 21, 25, 2, 12, 25, 26, 21, 25, 2, 26, 24, 21, 20, 10, 21, 25, 2, 30, 2, 19, 12, 2, 16, 24, 34, 2, 26, 8, 19, 9, 16, 34, 20, 2, 8, 2, 17, 27, 14, 8, 24, 6, 2, 2, 10, 27, 8, 20, 11, 21, 2, 18, 8, 25, 2, 26, 24, 12, 25, 2, 10, 8, 25, 16, 26, 8, 25, 2, 12, 25, 26, 27, 28, 16, 12, 24, 21, 20, 2, 26, 12, 24, 19, 16, 20, 8, 11, 8, 25, 4, 2, 18, 21, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 10, 8, 20, 26, 8, 9, 8, 20, 2, 30, 2, 9, 8, 16, 18, 8, 9, 8, 20, 2, 12, 20, 2, 18, 8, 2, 22, 27, 12, 24, 26, 8, 4, 2, 13, 12, 18, 16, 10, 12, 25, 2, 22, 21, 24, 2, 15, 8, 9, 12, 24, 2, 8, 10, 8, 9, 8, 11, 21, 2, 10, 21, 20, 2, 12, 18, 2, 22, 24, 21, 9, 18, 12, 19, 8, 7, 2, 2, 5, 32, 23, 27, 16, 34, 20, 2, 26, 12, 19, 12, 2, 8, 18, 2, 18, 21, 9, 21, 2, 13, 12, 24, 21, 31, 4, 2, 8, 18, 2, 18, 21, 9, 21, 4, 2, 8, 18, 2, 18, 21, 9, 21, 3, 2, 2, 5, 2, 32, 23, 27, 16, 34, 20, 2, 26, 12, 19, 12, 2, 8, 18, 2, 18, 21, 9, 21, 2, 13, 12, 24, 21, 31, 4, 2, 8, 18, 2, 18, 21, 9, 21, 2, 13, 12, 24, 21, 31, 3, 2, 11, 12, 26, 24, 33, 25, 2, 11, 12, 2, 27, 20, 2, 33, 24, 9, 21, 18, 2, 14, 24, 8, 20, 11, 12, 2, 8, 22, 8, 24, 12, 10, 16, 37, 2, 12, 18, 2, 18, 21, 9, 21, 4, 2, 24, 27, 14, 16, 12, 20, 11, 21, 2, 11, 12, 2, 15, 8, 19, 9, 24, 12, 2, 30, 2, 14, 24, 16, 26, 8, 20, 11, 21, 7, 2, 2, 5, 2, 10, 12, 24, 11, 16, 26, 21, 25, 4, 2, 32, 19, 12, 2, 18, 21, 25, 2, 28, 21, 30, 2, 8, 2, 10, 21, 19, 12, 24, 3, 2, 10, 8, 11, 8, 2, 27, 20, 21, 2, 25, 12, 2, 12, 25, 10, 21, 20, 11, 16, 37, 2, 12, 20, 2, 25, 27, 2, 10, 8, 25, 8, 4, 2, 22, 12, 20, 25, 8, 20, 11, 21, 2, 23, 27, 12, 2, 12, 25, 26, 8, 9, 8, 20, 2, 8, 2, 25, 8, 18, 28, 21, 4, 2, 22, 12, 24, 21, 2, 12, 18, 2, 18, 21, 9, 21, 2, 13, 12, 24, 21, 31, 2, 25, 12, 2, 12, 20, 10, 8, 19, 16, 20, 37, 2, 8, 2, 18, 8, 2, 10, 8, 25, 16, 26, 8, 2, 11, 12, 2, 22, 8, 17, 8, 2, 11 ...

# %% [markdown]
# ##P3. preparar nuestros datos de entrenamiento
#
# ---
#
#
# 1.   Primero debemos transformar la lista de secuencias de entrada en la forma [muestras, pasos de tiempo, características] esperada por una red LSTM.
# 2.   Luego debemos cambiar la escala de los números enteros al rango de 0 a 1 para que los patrones sean más fáciles de aprender mediante la red LSTM que utiliza la función de activación sigmoidea de forma predeterminada.
# 3.   por ultimo necesitamos convertir los patrones de salida (caracteres individuales convertidos en enteros) en una codificación one hot. Esto es para que podamos configurar la red para predecir la probabilidad de cada uno de los 54 caracteres diferentes en el vocabulario (una representación más fácil)

# %%
#transformar la lista X de secuencias de entrada en la forma [muestras (3091), pasos de tiempo, características]
X = np.reshape(dataX, (n_patterns, seq_length, 1))
# normalizar (cambiar la escala de los números enteros al rango de 0 a 1 )
X = X / float(n_vocab)
# convertir los patrones de salida (caracteres individuales convertidos en enteros) en una codificación one hot.
y = tf.keras.utils.to_categorical(dataY)

# %% [markdown]
# ##P4.Construcción del modelo RNN
#
# ---
# definimos nuestro modelo LSTM:
# Aquí definimos una única capa LSTM oculta con 256 unidades de memoria. La red usa deserción con una probabilidad de 20. La capa de salida es una capa densa que usa la función de activación softmax para generar una predicción de probabilidad para cada uno de los 54 caracteres entre 0 y 1.

# %%
# define the LSTM model

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(256, input_shape=(X.shape[1], X.shape[2])))    #creamos una capa con 256 unidades de memoria
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(y.shape[1], activation='softmax'))            #Softmax convierte un vector de valores en una distribución de probabilidad para cada uno de los 39
                                                                              #Softmax se utiliza a menudo como la activación para la última capa de una red de clasificación
#utilizamos el algoritmo de optimización de ADAM para la velocidad
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %% [markdown]
# ###P4.1 Creando chekpoints
#
# ---
#
# La red es lenta de entrenar (alrededor de 300 segundos por época) teniendo activa la GPU, ASí que crearemos CHECKPOINTS (puntos de control) para registrar todos los pesos de la red para archivar cada vez que se observe una mejora en la pérdida al final de la época. Usaremos el mejor conjunto de pesos (menor pérdida) para instanciar nuestro modelo generativo en la siguiente sección

# %%
# definimos  una carpeta para guardar los checkpoint
filepath="checkpoints/weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %% [markdown]
# ###P4.2 entrenando

# %%
history = model.fit(X, y, epochs=1000, batch_size=128, verbose=1,callbacks=callbacks_list)
# Out:
# Epoch 1/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 3.2145
# Epoch 1: loss improved from inf to 3.21075, saving model to checkpoints/weights-improvement-01-3.2108.hdf5
# 25/25 [==============================] - 7s 26ms/step - loss: 3.2108
# Epoch 2/1000
# 25/25 [==============================] - ETA: 0s - loss: 3.0002
# Epoch 2: loss improved from 3.21075 to 3.00017, saving model to checkpoints/weights-improvement-02-3.0002.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 3.0002
# Epoch 3/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9843
# Epoch 3: loss improved from 3.00017 to 2.98430, saving model to checkpoints/weights-improvement-03-2.9843.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9843
# Epoch 4/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9897
# Epoch 4: loss did not improve from 2.98430
# 25/25 [==============================] - 1s 20ms/step - loss: 2.9897
# Epoch 5/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9737
# Epoch 5: loss improved from 2.98430 to 2.97375, saving model to checkpoints/weights-improvement-05-2.9737.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 2.9737
# Epoch 6/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9732
# Epoch 6: loss improved from 2.97375 to 2.97324, saving model to checkpoints/weights-improvement-06-2.9732.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9732
# Epoch 7/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9811
# Epoch 7: loss did not improve from 2.97324
# 25/25 [==============================] - 0s 20ms/step - loss: 2.9811
# Epoch 8/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9677
# Epoch 8: loss improved from 2.97324 to 2.96774, saving model to checkpoints/weights-improvement-08-2.9677.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9677
# Epoch 9/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9758
# Epoch 9: loss did not improve from 2.96774
# 25/25 [==============================] - 0s 20ms/step - loss: 2.9758
# Epoch 10/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9668
# Epoch 10: loss improved from 2.96774 to 2.96675, saving model to checkpoints/weights-improvement-10-2.9668.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9668
# Epoch 11/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 2.9633
# Epoch 11: loss improved from 2.96675 to 2.96447, saving model to checkpoints/weights-improvement-11-2.9645.hdf5
# 25/25 [==============================] - 1s 24ms/step - loss: 2.9645
# Epoch 12/1000
# 23/25 [==========================>...] - ETA: 0s - loss: 2.9594
# Epoch 12: loss did not improve from 2.96447
# 25/25 [==============================] - 1s 22ms/step - loss: 2.9664
# Epoch 13/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9666
# Epoch 13: loss did not improve from 2.96447
# 25/25 [==============================] - 0s 20ms/step - loss: 2.9666
# Epoch 14/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9654
# Epoch 14: loss did not improve from 2.96447
# 25/25 [==============================] - 0s 19ms/step - loss: 2.9654
# Epoch 15/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9636
# Epoch 15: loss improved from 2.96447 to 2.96357, saving model to checkpoints/weights-improvement-15-2.9636.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9636
# Epoch 16/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9613
# Epoch 16: loss improved from 2.96357 to 2.96127, saving model to checkpoints/weights-improvement-16-2.9613.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9613
# Epoch 17/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9554
# Epoch 17: loss improved from 2.96127 to 2.95539, saving model to checkpoints/weights-improvement-17-2.9554.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9554
# Epoch 18/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9551
# Epoch 18: loss improved from 2.95539 to 2.95515, saving model to checkpoints/weights-improvement-18-2.9551.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9551
# Epoch 19/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9541
# Epoch 19: loss improved from 2.95515 to 2.95412, saving model to checkpoints/weights-improvement-19-2.9541.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9541
# Epoch 20/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9501
# Epoch 20: loss improved from 2.95412 to 2.95012, saving model to checkpoints/weights-improvement-20-2.9501.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9501
# Epoch 21/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9470
# Epoch 21: loss improved from 2.95012 to 2.94703, saving model to checkpoints/weights-improvement-21-2.9470.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9470
# Epoch 22/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9408
# Epoch 22: loss improved from 2.94703 to 2.94085, saving model to checkpoints/weights-improvement-22-2.9408.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9408
# Epoch 23/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9314
# Epoch 23: loss improved from 2.94085 to 2.93143, saving model to checkpoints/weights-improvement-23-2.9314.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 2.9314
# Epoch 24/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9212
# Epoch 24: loss improved from 2.93143 to 2.92120, saving model to checkpoints/weights-improvement-24-2.9212.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 2.9212
# Epoch 25/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.9003
# Epoch 25: loss improved from 2.92120 to 2.90030, saving model to checkpoints/weights-improvement-25-2.9003.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 2.9003
# Epoch 26/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.8875
# Epoch 26: loss improved from 2.90030 to 2.88746, saving model to checkpoints/weights-improvement-26-2.8875.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 2.8875
# Epoch 27/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.8694
# Epoch 27: loss improved from 2.88746 to 2.86937, saving model to checkpoints/weights-improvement-27-2.8694.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.8694
# Epoch 28/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.8396
# Epoch 28: loss improved from 2.86937 to 2.83962, saving model to checkpoints/weights-improvement-28-2.8396.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.8396
# Epoch 29/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.8264
# Epoch 29: loss improved from 2.83962 to 2.82643, saving model to checkpoints/weights-improvement-29-2.8264.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.8264
# Epoch 30/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.8206
# Epoch 30: loss improved from 2.82643 to 2.82061, saving model to checkpoints/weights-improvement-30-2.8206.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.8206
# Epoch 31/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.7930
# Epoch 31: loss improved from 2.82061 to 2.79299, saving model to checkpoints/weights-improvement-31-2.7930.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 2.7930
# Epoch 32/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.7770
# Epoch 32: loss improved from 2.79299 to 2.77705, saving model to checkpoints/weights-improvement-32-2.7770.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.7770
# Epoch 33/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.7610
# Epoch 33: loss improved from 2.77705 to 2.76097, saving model to checkpoints/weights-improvement-33-2.7610.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.7610
# Epoch 34/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.7348
# Epoch 34: loss improved from 2.76097 to 2.73484, saving model to checkpoints/weights-improvement-34-2.7348.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.7348
# Epoch 35/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.7274
# Epoch 35: loss improved from 2.73484 to 2.72743, saving model to checkpoints/weights-improvement-35-2.7274.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.7274
# Epoch 36/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.7179
# Epoch 36: loss improved from 2.72743 to 2.71789, saving model to checkpoints/weights-improvement-36-2.7179.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.7179
# Epoch 37/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.6973
# Epoch 37: loss improved from 2.71789 to 2.69726, saving model to checkpoints/weights-improvement-37-2.6973.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.6973
# Epoch 38/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.6774
# Epoch 38: loss improved from 2.69726 to 2.67738, saving model to checkpoints/weights-improvement-38-2.6774.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.6774
# Epoch 39/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.6533
# Epoch 39: loss improved from 2.67738 to 2.65333, saving model to checkpoints/weights-improvement-39-2.6533.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.6533
# Epoch 40/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.6228
# Epoch 40: loss improved from 2.65333 to 2.62279, saving model to checkpoints/weights-improvement-40-2.6228.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.6228
# Epoch 41/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.5988
# Epoch 41: loss improved from 2.62279 to 2.59876, saving model to checkpoints/weights-improvement-41-2.5988.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 2.5988
# Epoch 42/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.5791
# Epoch 42: loss improved from 2.59876 to 2.57908, saving model to checkpoints/weights-improvement-42-2.5791.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.5791
# Epoch 43/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.5459
# Epoch 43: loss improved from 2.57908 to 2.54589, saving model to checkpoints/weights-improvement-43-2.5459.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.5459
# Epoch 44/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.4867
# Epoch 44: loss improved from 2.54589 to 2.48670, saving model to checkpoints/weights-improvement-44-2.4867.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 2.4867
# Epoch 45/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.4556
# Epoch 45: loss improved from 2.48670 to 2.45557, saving model to checkpoints/weights-improvement-45-2.4556.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.4556
# Epoch 46/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.4158
# Epoch 46: loss improved from 2.45557 to 2.41580, saving model to checkpoints/weights-improvement-46-2.4158.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.4158
# Epoch 47/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.3695
# Epoch 47: loss improved from 2.41580 to 2.36952, saving model to checkpoints/weights-improvement-47-2.3695.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.3695
# Epoch 48/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.3287
# Epoch 48: loss improved from 2.36952 to 2.32870, saving model to checkpoints/weights-improvement-48-2.3287.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.3287
# Epoch 49/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.2818
# Epoch 49: loss improved from 2.32870 to 2.28177, saving model to checkpoints/weights-improvement-49-2.2818.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.2818
# Epoch 50/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.2447
# Epoch 50: loss improved from 2.28177 to 2.24475, saving model to checkpoints/weights-improvement-50-2.2447.hdf5
# 25/25 [==============================] - 1s 23ms/step - loss: 2.2447
# Epoch 51/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.2161
# Epoch 51: loss improved from 2.24475 to 2.21614, saving model to checkpoints/weights-improvement-51-2.2161.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.2161
# Epoch 52/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.1628
# Epoch 52: loss improved from 2.21614 to 2.16284, saving model to checkpoints/weights-improvement-52-2.1628.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 2.1628
# Epoch 53/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.1104
# Epoch 53: loss improved from 2.16284 to 2.11040, saving model to checkpoints/weights-improvement-53-2.1104.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.1104
# Epoch 54/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.0864
# Epoch 54: loss improved from 2.11040 to 2.08641, saving model to checkpoints/weights-improvement-54-2.0864.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.0864
# Epoch 55/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.0679
# Epoch 55: loss improved from 2.08641 to 2.06787, saving model to checkpoints/weights-improvement-55-2.0679.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.0679
# Epoch 56/1000
# 25/25 [==============================] - ETA: 0s - loss: 2.0019
# Epoch 56: loss improved from 2.06787 to 2.00186, saving model to checkpoints/weights-improvement-56-2.0019.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.0019
# Epoch 57/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.9325
# Epoch 57: loss improved from 2.00186 to 1.93245, saving model to checkpoints/weights-improvement-57-1.9325.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.9325
# Epoch 58/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.9049
# Epoch 58: loss improved from 1.93245 to 1.90492, saving model to checkpoints/weights-improvement-58-1.9049.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.9049
# Epoch 59/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.8631
# Epoch 59: loss improved from 1.90492 to 1.86305, saving model to checkpoints/weights-improvement-59-1.8631.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.8631
# Epoch 60/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.8382
# Epoch 60: loss improved from 1.86305 to 1.83823, saving model to checkpoints/weights-improvement-60-1.8382.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.8382
# Epoch 61/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.7850
# Epoch 61: loss improved from 1.83823 to 1.78498, saving model to checkpoints/weights-improvement-61-1.7850.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.7850
# Epoch 62/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.7403
# Epoch 62: loss improved from 1.78498 to 1.74034, saving model to checkpoints/weights-improvement-62-1.7403.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.7403
# Epoch 63/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.6850
# Epoch 63: loss improved from 1.74034 to 1.68497, saving model to checkpoints/weights-improvement-63-1.6850.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 1.6850
# Epoch 64/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.6303
# Epoch 64: loss improved from 1.68497 to 1.63034, saving model to checkpoints/weights-improvement-64-1.6303.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.6303
# Epoch 65/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.5935
# Epoch 65: loss improved from 1.63034 to 1.59354, saving model to checkpoints/weights-improvement-65-1.5935.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.5935
# Epoch 66/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.5484
# Epoch 66: loss improved from 1.59354 to 1.54845, saving model to checkpoints/weights-improvement-66-1.5484.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.5484
# Epoch 67/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.4899
# Epoch 67: loss improved from 1.54845 to 1.48991, saving model to checkpoints/weights-improvement-67-1.4899.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 1.4899
# Epoch 68/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.4528
# Epoch 68: loss improved from 1.48991 to 1.45277, saving model to checkpoints/weights-improvement-68-1.4528.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 1.4528
# Epoch 69/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.4312
# Epoch 69: loss improved from 1.45277 to 1.43121, saving model to checkpoints/weights-improvement-69-1.4312.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 1.4312
# Epoch 70/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.3707
# Epoch 70: loss improved from 1.43121 to 1.37069, saving model to checkpoints/weights-improvement-70-1.3707.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.3707
# Epoch 71/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.3501
# Epoch 71: loss improved from 1.37069 to 1.35011, saving model to checkpoints/weights-improvement-71-1.3501.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.3501
# Epoch 72/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.2484
# Epoch 72: loss improved from 1.35011 to 1.24838, saving model to checkpoints/weights-improvement-72-1.2484.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.2484
# Epoch 73/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.2551
# Epoch 73: loss did not improve from 1.24838
# 25/25 [==============================] - 1s 20ms/step - loss: 1.2551
# Epoch 74/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.1864
# Epoch 74: loss improved from 1.24838 to 1.18637, saving model to checkpoints/weights-improvement-74-1.1864.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.1864
# Epoch 75/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.1315
# Epoch 75: loss improved from 1.18637 to 1.13153, saving model to checkpoints/weights-improvement-75-1.1315.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.1315
# Epoch 76/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.0802
# Epoch 76: loss improved from 1.13153 to 1.08015, saving model to checkpoints/weights-improvement-76-1.0802.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.0802
# Epoch 77/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.0545
# Epoch 77: loss improved from 1.08015 to 1.05451, saving model to checkpoints/weights-improvement-77-1.0545.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 1.0545
# Epoch 78/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.9951
# Epoch 78: loss improved from 1.05451 to 0.99511, saving model to checkpoints/weights-improvement-78-0.9951.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.9951
# Epoch 79/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.9544
# Epoch 79: loss improved from 0.99511 to 0.95441, saving model to checkpoints/weights-improvement-79-0.9544.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.9544
# Epoch 80/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.9182
# Epoch 80: loss improved from 0.95441 to 0.91815, saving model to checkpoints/weights-improvement-80-0.9182.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.9182
# Epoch 81/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.9035
# Epoch 81: loss improved from 0.91815 to 0.90350, saving model to checkpoints/weights-improvement-81-0.9035.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.9035
# Epoch 82/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.8569
# Epoch 82: loss improved from 0.90350 to 0.85685, saving model to checkpoints/weights-improvement-82-0.8569.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.8569
# Epoch 83/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.7697
# Epoch 83: loss improved from 0.85685 to 0.76971, saving model to checkpoints/weights-improvement-83-0.7697.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.7697
# Epoch 84/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.7607
# Epoch 84: loss improved from 0.76971 to 0.76075, saving model to checkpoints/weights-improvement-84-0.7607.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.7607
# Epoch 85/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.7361
# Epoch 85: loss improved from 0.76075 to 0.73607, saving model to checkpoints/weights-improvement-85-0.7361.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.7361
# Epoch 86/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.6702
# Epoch 86: loss improved from 0.73607 to 0.67019, saving model to checkpoints/weights-improvement-86-0.6702.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.6702
# Epoch 87/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.6701
# Epoch 87: loss improved from 0.67019 to 0.67012, saving model to checkpoints/weights-improvement-87-0.6701.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.6701
# Epoch 88/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.5958
# Epoch 88: loss improved from 0.67012 to 0.59584, saving model to checkpoints/weights-improvement-88-0.5958.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5958
# Epoch 89/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.5885
# Epoch 89: loss improved from 0.59584 to 0.58852, saving model to checkpoints/weights-improvement-89-0.5885.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5885
# Epoch 90/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.5674
# Epoch 90: loss improved from 0.58852 to 0.56744, saving model to checkpoints/weights-improvement-90-0.5674.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5674
# Epoch 91/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.5605
# Epoch 91: loss improved from 0.56744 to 0.56053, saving model to checkpoints/weights-improvement-91-0.5605.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5605
# Epoch 92/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.4919
# Epoch 92: loss improved from 0.56053 to 0.49189, saving model to checkpoints/weights-improvement-92-0.4919.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4919
# Epoch 93/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.4351
# Epoch 93: loss improved from 0.49189 to 0.43507, saving model to checkpoints/weights-improvement-93-0.4351.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4351
# Epoch 94/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.4091
# Epoch 94: loss improved from 0.43507 to 0.40912, saving model to checkpoints/weights-improvement-94-0.4091.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4091
# Epoch 95/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.3767
# Epoch 95: loss improved from 0.40912 to 0.37670, saving model to checkpoints/weights-improvement-95-0.3767.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.3767
# Epoch 96/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 0.3864
# Epoch 96: loss did not improve from 0.37670
# 25/25 [==============================] - 1s 20ms/step - loss: 0.3873
# Epoch 97/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.4344
# Epoch 97: loss did not improve from 0.37670
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4344
# Epoch 98/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.3860
# Epoch 98: loss did not improve from 0.37670
# 25/25 [==============================] - 1s 20ms/step - loss: 0.3860
# Epoch 99/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.3299
# Epoch 99: loss improved from 0.37670 to 0.32991, saving model to checkpoints/weights-improvement-99-0.3299.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.3299
# Epoch 100/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.3032
# Epoch 100: loss improved from 0.32991 to 0.30319, saving model to checkpoints/weights-improvement-100-0.3032.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.3032
# Epoch 101/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2854
# Epoch 101: loss improved from 0.30319 to 0.28541, saving model to checkpoints/weights-improvement-101-0.2854.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.2854
# Epoch 102/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2680
# Epoch 102: loss improved from 0.28541 to 0.26800, saving model to checkpoints/weights-improvement-102-0.2680.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2680
# Epoch 103/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2826
# Epoch 103: loss did not improve from 0.26800
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2826
# Epoch 104/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2582
# Epoch 104: loss improved from 0.26800 to 0.25816, saving model to checkpoints/weights-improvement-104-0.2582.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2582
# Epoch 105/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2148
# Epoch 105: loss improved from 0.25816 to 0.21482, saving model to checkpoints/weights-improvement-105-0.2148.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.2148
# Epoch 106/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2024
# Epoch 106: loss improved from 0.21482 to 0.20235, saving model to checkpoints/weights-improvement-106-0.2024.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2024
# Epoch 107/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1891
# Epoch 107: loss improved from 0.20235 to 0.18913, saving model to checkpoints/weights-improvement-107-0.1891.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.1891
# Epoch 108/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1577
# Epoch 108: loss improved from 0.18913 to 0.15771, saving model to checkpoints/weights-improvement-108-0.1577.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.1577
# Epoch 109/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1820
# Epoch 109: loss did not improve from 0.15771
# 25/25 [==============================] - 0s 20ms/step - loss: 0.1820
# Epoch 110/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2324
# Epoch 110: loss did not improve from 0.15771
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2324
# Epoch 111/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2589
# Epoch 111: loss did not improve from 0.15771
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2589
# Epoch 112/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2336
# Epoch 112: loss did not improve from 0.15771
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2336
# Epoch 113/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2175
# Epoch 113: loss did not improve from 0.15771
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2175
# Epoch 114/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2000
# Epoch 114: loss did not improve from 0.15771
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2000
# Epoch 115/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1523
# Epoch 115: loss improved from 0.15771 to 0.15232, saving model to checkpoints/weights-improvement-115-0.1523.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.1523
# Epoch 116/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1343
# Epoch 116: loss improved from 0.15232 to 0.13434, saving model to checkpoints/weights-improvement-116-0.1343.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.1343
# Epoch 117/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1138
# Epoch 117: loss improved from 0.13434 to 0.11377, saving model to checkpoints/weights-improvement-117-0.1138.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.1138
# Epoch 118/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1063
# Epoch 118: loss improved from 0.11377 to 0.10633, saving model to checkpoints/weights-improvement-118-0.1063.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.1063
# Epoch 119/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0950
# Epoch 119: loss improved from 0.10633 to 0.09497, saving model to checkpoints/weights-improvement-119-0.0950.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0950
# Epoch 120/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1132
# Epoch 120: loss did not improve from 0.09497
# 25/25 [==============================] - 1s 20ms/step - loss: 0.1132
# Epoch 121/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1101
# Epoch 121: loss did not improve from 0.09497
# 25/25 [==============================] - 1s 20ms/step - loss: 0.1101
# Epoch 122/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1096
# Epoch 122: loss did not improve from 0.09497
# 25/25 [==============================] - 1s 20ms/step - loss: 0.1096
# Epoch 123/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0939
# Epoch 123: loss improved from 0.09497 to 0.09391, saving model to checkpoints/weights-improvement-123-0.0939.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0939
# Epoch 124/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0819
# Epoch 124: loss improved from 0.09391 to 0.08187, saving model to checkpoints/weights-improvement-124-0.0819.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0819
# Epoch 125/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0753
# Epoch 125: loss improved from 0.08187 to 0.07528, saving model to checkpoints/weights-improvement-125-0.0753.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0753
# Epoch 126/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0684
# Epoch 126: loss improved from 0.07528 to 0.06842, saving model to checkpoints/weights-improvement-126-0.0684.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0684
# Epoch 127/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0626
# Epoch 127: loss improved from 0.06842 to 0.06257, saving model to checkpoints/weights-improvement-127-0.0626.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0626
# Epoch 128/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0626
# Epoch 128: loss improved from 0.06257 to 0.06238, saving model to checkpoints/weights-improvement-128-0.0624.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0624
# Epoch 129/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0577
# Epoch 129: loss improved from 0.06238 to 0.05774, saving model to checkpoints/weights-improvement-129-0.0577.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0577
# Epoch 130/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0584
# Epoch 130: loss did not improve from 0.05774
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0584
# Epoch 131/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0526
# Epoch 131: loss improved from 0.05774 to 0.05260, saving model to checkpoints/weights-improvement-131-0.0526.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0526
# Epoch 132/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0510
# Epoch 132: loss improved from 0.05260 to 0.05099, saving model to checkpoints/weights-improvement-132-0.0510.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0510
# Epoch 133/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0515
# Epoch 133: loss did not improve from 0.05099
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0515
# Epoch 134/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0529
# Epoch 134: loss did not improve from 0.05099
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0529
# Epoch 135/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0515
# Epoch 135: loss did not improve from 0.05099
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0515
# Epoch 136/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0480
# Epoch 136: loss improved from 0.05099 to 0.04803, saving model to checkpoints/weights-improvement-136-0.0480.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0480
# Epoch 137/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0734
# Epoch 137: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0734
# Epoch 138/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2508
# Epoch 138: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2508
# Epoch 139/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2962
# Epoch 139: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2962
# Epoch 140/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.3138
# Epoch 140: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.3138
# Epoch 141/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2629
# Epoch 141: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2629
# Epoch 142/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2068
# Epoch 142: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2068
# Epoch 143/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1487
# Epoch 143: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.1487
# Epoch 144/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1022
# Epoch 144: loss did not improve from 0.04803
# 25/25 [==============================] - 0s 20ms/step - loss: 0.1022
# Epoch 145/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0780
# Epoch 145: loss did not improve from 0.04803
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0780
# Epoch 146/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0656
# Epoch 146: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0656
# Epoch 147/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0585
# Epoch 147: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0585
# Epoch 148/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0546
# Epoch 148: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0546
# Epoch 149/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0490
# Epoch 149: loss did not improve from 0.04803
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0490
# Epoch 150/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0419
# Epoch 150: loss improved from 0.04803 to 0.04187, saving model to checkpoints/weights-improvement-150-0.0419.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0419
# Epoch 151/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0401
# Epoch 151: loss improved from 0.04187 to 0.04007, saving model to checkpoints/weights-improvement-151-0.0401.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0401
# Epoch 152/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0347
# Epoch 152: loss improved from 0.04007 to 0.03467, saving model to checkpoints/weights-improvement-152-0.0347.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0347
# Epoch 153/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0343
# Epoch 153: loss improved from 0.03467 to 0.03428, saving model to checkpoints/weights-improvement-153-0.0343.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0343
# Epoch 154/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0342
# Epoch 154: loss improved from 0.03428 to 0.03416, saving model to checkpoints/weights-improvement-154-0.0342.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0342
# Epoch 155/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0352
# Epoch 155: loss did not improve from 0.03416
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0352
# Epoch 156/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0316
# Epoch 156: loss improved from 0.03416 to 0.03162, saving model to checkpoints/weights-improvement-156-0.0316.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0316
# Epoch 157/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0282
# Epoch 157: loss improved from 0.03162 to 0.02822, saving model to checkpoints/weights-improvement-157-0.0282.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0282
# Epoch 158/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0264
# Epoch 158: loss improved from 0.02822 to 0.02636, saving model to checkpoints/weights-improvement-158-0.0264.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0264
# Epoch 159/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0245
# Epoch 159: loss improved from 0.02636 to 0.02450, saving model to checkpoints/weights-improvement-159-0.0245.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0245
# Epoch 160/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0267
# Epoch 160: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0267
# Epoch 161/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0278
# Epoch 161: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0278
# Epoch 162/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0300
# Epoch 162: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0300
# Epoch 163/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0266
# Epoch 163: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0266
# Epoch 164/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1098
# Epoch 164: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 21ms/step - loss: 0.1098
# Epoch 165/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1603
# Epoch 165: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.1603
# Epoch 166/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2432
# Epoch 166: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2432
# Epoch 167/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2302
# Epoch 167: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2302
# Epoch 168/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.2224
# Epoch 168: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2224
# Epoch 169/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1492
# Epoch 169: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.1492
# Epoch 170/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0963
# Epoch 170: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0963
# Epoch 171/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0659
# Epoch 171: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0659
# Epoch 172/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0578
# Epoch 172: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0578
# Epoch 173/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0476
# Epoch 173: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0476
# Epoch 174/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0397
# Epoch 174: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0397
# Epoch 175/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 175: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0314
# Epoch 176/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0329
# Epoch 176: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0329
# Epoch 177/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0327
# Epoch 177: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0327
# Epoch 178/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0313
# Epoch 178: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0313
# Epoch 179/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0307
# Epoch 179: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0307
# Epoch 180/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 180: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0273
# Epoch 181/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 181: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0291
# Epoch 182/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0336
# Epoch 182: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0336
# Epoch 183/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0312
# Epoch 183: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0312
# Epoch 184/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 184: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0279
# Epoch 185/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 185: loss did not improve from 0.02450
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0271
# Epoch 186/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0236
# Epoch 186: loss improved from 0.02450 to 0.02365, saving model to checkpoints/weights-improvement-186-0.0236.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0236
# Epoch 187/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 187: loss did not improve from 0.02365
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0249
# Epoch 188/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 188: loss did not improve from 0.02365
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0279
# Epoch 189/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0240
# Epoch 189: loss did not improve from 0.02365
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0240
# Epoch 190/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0212
# Epoch 190: loss improved from 0.02365 to 0.02120, saving model to checkpoints/weights-improvement-190-0.0212.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0212
# Epoch 191/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0188
# Epoch 191: loss improved from 0.02120 to 0.01884, saving model to checkpoints/weights-improvement-191-0.0188.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0188
# Epoch 192/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0177
# Epoch 192: loss improved from 0.01884 to 0.01772, saving model to checkpoints/weights-improvement-192-0.0177.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0177
# Epoch 193/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0173
# Epoch 193: loss improved from 0.01772 to 0.01726, saving model to checkpoints/weights-improvement-193-0.0173.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0173
# Epoch 194/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 194: loss improved from 0.01726 to 0.01663, saving model to checkpoints/weights-improvement-194-0.0166.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0166
# Epoch 195/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0187
# Epoch 195: loss did not improve from 0.01663
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0187
# Epoch 196/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 196: loss improved from 0.01663 to 0.01436, saving model to checkpoints/weights-improvement-196-0.0144.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0144
# Epoch 197/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 197: loss did not improve from 0.01436
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0166
# Epoch 198/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 198: loss did not improve from 0.01436
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0167
# Epoch 199/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 199: loss did not improve from 0.01436
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0159
# Epoch 200/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 200: loss did not improve from 0.01436
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0170
# Epoch 201/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 201: loss improved from 0.01436 to 0.01395, saving model to checkpoints/weights-improvement-201-0.0140.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0140
# Epoch 202/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 202: loss did not improve from 0.01395
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0157
# Epoch 203/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 203: loss did not improve from 0.01395
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0198
# Epoch 204/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0188
# Epoch 204: loss did not improve from 0.01395
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0188
# Epoch 205/1000
# ...
# Epoch 918: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0122
# Epoch 919/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119
# Epoch 919: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0119
# Epoch 920/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 920: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0107
# Epoch 921/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 921: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0130
# Epoch 922/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 922: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0095
# Epoch 923/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 923: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0092
# Epoch 924/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 924: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0090
# Epoch 925/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 925: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0084
# Epoch 926/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 926: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084
# Epoch 927/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 927: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0102
# Epoch 928/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 928: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0073
# Epoch 929/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 929: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0074
# Epoch 930/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 930: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075
# Epoch 931/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 931: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080
# Epoch 932/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 932: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084
# Epoch 933/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 933: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0087
# Epoch 934/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 934: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0077
# Epoch 935/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 935: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0086
# Epoch 936/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 936: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076
# Epoch 937/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 937: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072
# Epoch 938/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 938: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0065
# Epoch 939/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 939: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086
# Epoch 940/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 940: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0060
# Epoch 941/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 941: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074
# Epoch 942/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 942: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070
# Epoch 943/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 943: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0100
# Epoch 944/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 944: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0065
# Epoch 945/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0086
# Epoch 945: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086
# Epoch 946/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 946: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067
# Epoch 947/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 947: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075
# Epoch 948/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 948: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062
# Epoch 949/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 949: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0054
# Epoch 950/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 950: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0060
# Epoch 951/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 951: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0060
# Epoch 952/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 952: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063
# Epoch 953/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 953: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0066
# Epoch 954/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 954: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0048
# Epoch 955/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 955: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0055
# Epoch 956/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 956: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0047
# Epoch 957/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 957: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062
# Epoch 958/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0068
# Epoch 958: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067
# Epoch 959/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 959: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064
# Epoch 960/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 960: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0061
# Epoch 961/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 961: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074
# Epoch 962/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 962: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071
# Epoch 963/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0067
# Epoch 963: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067
# Epoch 964/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0060
# Epoch 964: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0060
# Epoch 965/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 965: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0065
# Epoch 966/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 966: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072
# Epoch 967/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 967: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0053
# Epoch 968/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 968: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0055
# Epoch 969/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 969: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066
# Epoch 970/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 970: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066
# Epoch 971/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 971: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0060
# Epoch 972/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 972: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0064
# Epoch 973/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 973: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0060
# Epoch 974/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 974: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0047
# Epoch 975/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 975: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0053
# Epoch 976/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 976: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0046
# Epoch 977/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 977: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0036
# Epoch 978/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 978: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0037
# Epoch 979/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 979: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059
# Epoch 980/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 980: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0050
# Epoch 981/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 981: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0064
# Epoch 982/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 982: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073
# Epoch 983/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 983: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066
# Epoch 984/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 984: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0043
# Epoch 985/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 985: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0071
# Epoch 986/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 986: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0083
# Epoch 987/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 987: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0100
# Epoch 988/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 988: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0097
# Epoch 989/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 989: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0126
# Epoch 990/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 990: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0277
# Epoch 991/1000
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0563
# Epoch 991: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0560
# Epoch 992/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0627
# Epoch 992: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0627
# Epoch 993/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0836
# Epoch 993: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0836
# Epoch 994/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1194
# Epoch 994: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.1194
# Epoch 995/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0546
# Epoch 995: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0546
# Epoch 996/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0275
# Epoch 996: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0275
# Epoch 997/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 997: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0185
# Epoch 998/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 998: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0140
# Epoch 999/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0106
# Epoch 999: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0106
# Epoch 1000/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 1000: loss did not improve from 0.00344
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0100

# %% [markdown]
# ##P5.Generando texto con una red LSTM
#
#
# ---
# Vamos a cargar el ultimo CHECKPOINT de entrenamiento y con el haremos MAGIA!!!

# %%
filename = "/content/checkpoints/weights-improvement-99-0.3299.hdf5"
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %% [markdown]
# ###P5.1 mapeo inverso (números a letras)
# creamos un mapeo inverso que podamos usar para convertir los números enteros nuevamente en caracteres para que podamos entender las predicciones

# %%
int_to_char = dict((i, c) for i, c in enumerate(chars))

# %% [markdown]
# ###P5.2 hacer predicciones
# La forma más sencilla de utilizar el modelo Keras LSTM para hacer predicciones es comenzar primero con una secuencia semilla como entrada, generar el siguiente carácter y luego actualizar la secuencia semilla para agregar el carácter generado al final y recortar el primer carácter. Este proceso se repite mientras queramos predecir nuevos caracteres (por ejemplo, una secuencia de 1000 caracteres de longitud).

# %%
# elige una semilla al azar
start = np.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print ("Semilla:")
print ("\"" + " ".join([int_to_char[value] for value in pattern])+"\"")
# generación de 10000 caracteres
for i in range(1000):
	x = np.reshape(pattern, (1, len(pattern), 1))
	x = x / float(n_vocab)
	prediction = model.predict(x, verbose=0)
	index = np.argmax(prediction)
	result = int_to_char[index]
	seq_in = [int_to_char[value] for value in pattern]
	sys.stdout.write(result)
	pattern.append(index)
	pattern = pattern[1:len(pattern)]
print ("\nDone.")
# Out:
# Semilla:
# "o :   -   ¡ c e r d i t o s ,   a b r i d m e   l a   p u e r t a !   -   n o ,   n o ,   n o ,   n"
# o te vayos a abrir. - pues si no me abrís... ¡soplaré y soplaré y la casita derribaré!  y se puso a soplar tan fuerte como el viento de invierro. sopló y sopló, pero la casita de ladrillos er  mu mesostenta  -¡cerdito, ábreme la puerta!  lnn hn mnoo do poboo  s noe peeee e seeigsn   fossss rire al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo feroz! - cantaban desde dentro los cerditos.  le nuevoe c no ve mactiedo sue fugrró a cis haro  e cadereede   nndder,snmmadrunto yos paretaa carira -e paes se sssoarua mos fu dtoo  d cacriinedo  a pu rtro cormoó y sos a laja a  aaaaaal  áe me lasí   casojr   -l¡quén teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo feroz! - cantaban desde dentro los cerditos.  le nuevoe c no ve mactiedo sue fugrró a cis haro  e cadereede   nndder,snmmadrunto yos paretaa carira -e paes se sssoarua mos fu dtoo  d cacriinedo  a pu rtro cormoó y sos a laja a  aaaaaal  áe me lasí   casojr   -l¡quén teme al lobo feroz, al
# Done.

# %% [markdown]
# ##P6.Mejorando la red (una LSTM más grande)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(256, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.LSTM(256))                                                                #agregaremos una segunda capa. 
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(y.shape[1], activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer='adam')
#cambiamos el nombre de archivo de los pesos con puntos de control para que 
#podamos distinguir entre los pesos de esta red 
filepath="weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"

# %% [markdown]
# ###P6.1 mejoramos el entrenamiento
#
# ---
# aumentamos las epoch y disminuiremos el tamaño del lote de 128 a 64 para darle a la red más oportunidades de actualizarse y aprender.

# %%
#los tiempos de entrenamiento aumentaran al doble que en la versión anterior
model.fit(X, y, epochs=50, batch_size=32, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 97/97 [==============================] - ETA: 0s - loss: 3.0429
# Epoch 1: loss did not improve from 0.00344
# 97/97 [==============================] - 7s 33ms/step - loss: 3.0429
# Epoch 2/50
# 97/97 [==============================] - ETA: 0s - loss: 2.9836
# Epoch 2: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.9836
# Epoch 3/50
# 97/97 [==============================] - ETA: 0s - loss: 2.9840
# Epoch 3: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.9840
# Epoch 4/50
# 97/97 [==============================] - ETA: 0s - loss: 2.9760
# Epoch 4: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 2.9760
# Epoch 5/50
# 97/97 [==============================] - ETA: 0s - loss: 2.9715
# Epoch 5: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.9715
# Epoch 6/50
# 97/97 [==============================] - ETA: 0s - loss: 2.9616
# Epoch 6: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.9616
# Epoch 7/50
# 97/97 [==============================] - ETA: 0s - loss: 2.9393
# Epoch 7: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.9393
# Epoch 8/50
# 97/97 [==============================] - ETA: 0s - loss: 2.9246
# Epoch 8: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 2.9246
# Epoch 9/50
# 97/97 [==============================] - ETA: 0s - loss: 2.8745
# Epoch 9: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.8745
# Epoch 10/50
# 97/97 [==============================] - ETA: 0s - loss: 2.8207
# Epoch 10: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.8207
# Epoch 11/50
# 97/97 [==============================] - ETA: 0s - loss: 2.7636
# Epoch 11: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 2.7636
# Epoch 12/50
# 97/97 [==============================] - ETA: 0s - loss: 2.7032
# Epoch 12: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.7032
# Epoch 13/50
# 97/97 [==============================] - ETA: 0s - loss: 2.6349
# Epoch 13: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.6349
# Epoch 14/50
# 97/97 [==============================] - ETA: 0s - loss: 2.5231
# Epoch 14: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 2.5231
# Epoch 15/50
# 97/97 [==============================] - ETA: 0s - loss: 2.4455
# Epoch 15: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 2.4455
# Epoch 16/50
# 97/97 [==============================] - ETA: 0s - loss: 2.3180
# Epoch 16: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 2.3180
# Epoch 17/50
# 97/97 [==============================] - ETA: 0s - loss: 2.2026
# Epoch 17: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 2.2026
# Epoch 18/50
# 97/97 [==============================] - ETA: 0s - loss: 2.1182
# Epoch 18: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 2.1182
# Epoch 19/50
# 97/97 [==============================] - ETA: 0s - loss: 2.0238
# Epoch 19: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 2.0238
# Epoch 20/50
# 97/97 [==============================] - ETA: 0s - loss: 1.9111
# Epoch 20: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 1.9111
# Epoch 21/50
# 97/97 [==============================] - ETA: 0s - loss: 1.7996
# Epoch 21: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 1.7996
# Epoch 22/50
# 97/97 [==============================] - ETA: 0s - loss: 1.6985
# Epoch 22: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 1.6985
# Epoch 23/50
# 97/97 [==============================] - ETA: 0s - loss: 1.5869
# Epoch 23: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 1.5869
# Epoch 24/50
# 97/97 [==============================] - ETA: 0s - loss: 1.4962
# Epoch 24: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 1.4962
# Epoch 25/50
# 97/97 [==============================] - ETA: 0s - loss: 1.3910
# Epoch 25: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 1.3910
# Epoch 26/50
# 97/97 [==============================] - ETA: 0s - loss: 1.2934
# Epoch 26: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 1.2934
# Epoch 27/50
# 97/97 [==============================] - ETA: 0s - loss: 1.1797
# Epoch 27: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 1.1797
# Epoch 28/50
# 97/97 [==============================] - ETA: 0s - loss: 1.0799
# Epoch 28: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 1.0799
# Epoch 29/50
# 97/97 [==============================] - ETA: 0s - loss: 0.9832
# Epoch 29: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.9832
# Epoch 30/50
# 97/97 [==============================] - ETA: 0s - loss: 0.8848
# Epoch 30: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 0.8848
# Epoch 31/50
# 97/97 [==============================] - ETA: 0s - loss: 0.8081
# Epoch 31: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.8081
# Epoch 32/50
# 97/97 [==============================] - ETA: 0s - loss: 0.7116
# Epoch 32: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.7116
# Epoch 33/50
# 97/97 [==============================] - ETA: 0s - loss: 0.6300
# Epoch 33: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.6300
# Epoch 34/50
# 97/97 [==============================] - ETA: 0s - loss: 0.5470
# Epoch 34: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.5470
# Epoch 35/50
# 97/97 [==============================] - ETA: 0s - loss: 0.5055
# Epoch 35: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.5055
# Epoch 36/50
# 97/97 [==============================] - ETA: 0s - loss: 0.4473
# Epoch 36: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.4473
# Epoch 37/50
# 97/97 [==============================] - ETA: 0s - loss: 0.3813
# Epoch 37: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.3813
# Epoch 38/50
# 97/97 [==============================] - ETA: 0s - loss: 0.3332
# Epoch 38: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.3332
# Epoch 39/50
# 97/97 [==============================] - ETA: 0s - loss: 0.2897
# Epoch 39: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.2897
# Epoch 40/50
# 97/97 [==============================] - ETA: 0s - loss: 0.2630
# Epoch 40: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.2630
# Epoch 41/50
# 97/97 [==============================] - ETA: 0s - loss: 0.2392
# Epoch 41: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.2392
# Epoch 42/50
# 97/97 [==============================] - ETA: 0s - loss: 0.2083
# Epoch 42: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.2083
# Epoch 43/50
# 97/97 [==============================] - ETA: 0s - loss: 0.1877
# Epoch 43: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.1877
# Epoch 44/50
# 97/97 [==============================] - ETA: 0s - loss: 0.1607
# Epoch 44: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 0.1607
# Epoch 45/50
# 97/97 [==============================] - ETA: 0s - loss: 0.1663
# Epoch 45: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 0.1663
# Epoch 46/50
# 97/97 [==============================] - ETA: 0s - loss: 0.1468
# Epoch 46: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.1468
# Epoch 47/50
# 97/97 [==============================] - ETA: 0s - loss: 0.1213
# Epoch 47: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 32ms/step - loss: 0.1213
# Epoch 48/50
# 97/97 [==============================] - ETA: 0s - loss: 0.1096
# Epoch 48: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 0.1096
# Epoch 49/50
# 97/97 [==============================] - ETA: 0s - loss: 0.1002
# Epoch 49: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 0.1002
# Epoch 50/50
# 97/97 [==============================] - ETA: 0s - loss: 0.0946
# Epoch 50: loss did not improve from 0.00344
# 97/97 [==============================] - 3s 31ms/step - loss: 0.0946

# %% [markdown]
# ###P6.2 haciendo predicciones

# %%
# elige una semilla al azar
start = np.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print ("Semilla:")
print ("\"" + " ".join([int_to_char[value] for value in pattern])+"\"")
# generación de caracteres
for i in range(1000):
	x = np.reshape(pattern, (1, len(pattern), 1))
	x = x / float(n_vocab)
	prediction = model.predict(x, verbose=0)
	index = np.argmax(prediction)
	result = int_to_char[index]
	seq_in = [int_to_char[value] for value in pattern]
	sys.stdout.write(result)
	pattern.append(index)
	pattern = pattern[1:len(pattern)]
print ("\nDone.")
# Out:
# Semilla:
# "b r i e n t o ,   y   a h o r a   d e s e a b a   c o m e r s e   a   l o s   t r e s   c e r d i t"
# os más que nunca, y frente a la puerta dijo:  - ¡cerditos, abridme la puerta! - no, no, no, no te vamos a abrir.  - pues si no me abres... ¡soplaré y soplaré y la casita derribaré! y sopló con todas sus fuerzas, sopló y sopló y la casita de paja se vino abajo. el cerdito pequeño corrió lo más rápido que pudo y entró en la casa de madera del hermano mediano. - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al lobo feroz, al lobo, al lobo!  - ¡quién teme al
# Done.

# %% [markdown]
# ##P7. exportar modelo RNN

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.21.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)

# %%
from keras.models import model_from_json
import os
# Serializamos el modelo en forma JSON
model_json = model.to_json()
with open("modelRNN_cuentos.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/modeloRNN_cuentosPesos.hdf5")
model.save('modelRNN_cuentos_v_h5.h5')
print("modelo salvado en disco")
# Out:
# modelo salvado en disco

# %% [markdown]
# ###P7.1 cargando un modelo

# %%
# Recrea exactamente el mismo modelo solo desde el archivo
import keras
import numpy
new_model = keras.models.load_model('/content/modelRNN_cuentos_v_h5.h5')

# %%
chars = sorted(list(set("comiendo una manzana")))
char_to_int = dict((c, i) for i, c in enumerate(chars))
n_chars = len(raw_text)
n_vocab = len(chars)
print("En total hay %d caracteres, y el diccionario tiene un tamaño de %d caracteres." % (n_chars, n_vocab))
pattern = dataX[5]
print(pattern)
# Out:
# En total hay 3141 caracteres, y el diccionario tiene un tamaño de 11 caracteres.
# [2, 27, 20, 8, 2, 28, 12, 31, 2, 26, 24, 12, 25, 2, 10, 12, 24, 11, 16, 26, 21, 25, 2, 23, 27, 12, 2, 12, 24, 8, 20, 2, 15, 12, 24, 19, 8, 20, 21, 25, 2, 30, 2, 25, 12, 2, 13, 27, 12, 24]

# %%
start = numpy.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print ("Semilla:")
print ("\"" + " ".join([int_to_char[value] for value in pattern])+"\"")
# generación de caracteres
for i in range(1000):
	x = numpy.reshape(pattern, (1, len(pattern), 1))
	x = x / float(n_vocab)
	prediction = new_model.predict(x, verbose=0)
	index = numpy.argmax(prediction)
	result = int_to_char[index]
	seq_in = [int_to_char[value] for value in pattern]
	sys.stdout.write(result)
	pattern.append(index)
	pattern = pattern[1:len(pattern)]
print ("\nDone.")
# Out:
# Semilla:
# "  e n   u n   s a n t i a m é n   c o n   t o d o s   e s t o s   t r o n c o s   y   m e   i r é  "
# e p p l p p l l p l l p l l p l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l l l l l l l l l l l l l l l l l lo er e p l p l l

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #Ejemplo 2: generar texto de cuentos, usando Keras

# %% [markdown]
# ##Instalando librerias CUDA

# %%
#!pip list
# !nvcc --version  #Version de CUDA en la maquina virtual
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# ##P0. importar librerias

# %%
#OPCIONAL 
# !pip install tensorflow-gpu #(opcional sobre para trabajar con EQUIPOS LOCALES..google colab ya la trae instalada)

# %%
import tensorflow as tf
import timeit               #para medir tiempos
import numpy as np
import pandas as pd 
import os
import time
import sys

# %% [markdown]
# ###P0.1 Uso de GPU para entrenar en tensorflow
#
# ---
# https://medium.com/analytics-vidhya/solution-to-tensorflow-2-not-using-gpu-119fb3e04daa

# %%
print("Tensorflow Version: ", tf.__version__)
print("Dispositivos disponibles para entrenar: ", tf.config.list_physical_devices())
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Encontrada la GPU: {}'.format(device_name))
# Out:
# Tensorflow Version:  2.7.0
# Dispositivos disponibles para entrenar:  [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Encontrada la GPU: /device:GPU:0

# %% [markdown]
# ###P0.2 probando rendimiento de CPU vs GPU

# %%
def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)

# %%
cpu()  #ejecutamos entrenamiento con CPU
gpu()  #ejecutamos entrenamiento con GPU
# Run the op several times.
print('TIEMPO (seg) para entrenar una red convolucional de 32x7x7x3 filtros sobre un randomico de 100x100x100x3 imagenes '
      '(batch x height x width x channel). suma de 10 epochs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# TIEMPO (seg) para entrenar una red convolucional de 32x7x7x3 filtros sobre un randomico de 100x100x100x3 imagenes (batch x height x width x channel). suma de 10 epochs.
# CPU (s):
# 3.8290878900000394
# GPU (s):
# 0.05176922499998682
# GPU speedup over CPU: 73x

# %% [markdown]
# ###P0.3 Dejando activo la GPU

# %%
#tf.device('/gpu:0') #activando la CPU
tf.device('/device:GPU:0') #activando la GPU

# %% [markdown]
# ##P0. Descarga y preprocesado de los datos

# %%
fileDL= tf.keras.utils.get_file('GatoConBotas.txt','https://raw.githubusercontent.com/GustavoAdolfoGuizaWalteros/Deep_Learning/main/Cuentos_txt/ElGatoConBotas.txt')
texto = open(fileDL, 'rb').read().decode(encoding='utf-8')

# %% [markdown]
# ###P0.1 limpiar/normalizar el texto
#
# ---
# *   pasar todo a minusculas
# *   convertir tildes a vocales sin tilde
# *   eliminar caracteres especiales (*#!()%=
# *   eliminar saltos de linea y tab (identación)

# %%
import re
from unicodedata import normalize
#pasa todo a minuscula
texto     = texto.lower()
#reemplazar tildes por letras similares sin tildes
transfor  = dict.fromkeys(map(ord, u'\u0301\u0308'), None)
texto     = normalize('NFKC', normalize('NFKD', texto).translate(transfor))
#quitar saltos de linea
texto      = texto.strip()
texto      = re.sub('\r|\n', ' ',texto)
#quitar espacios dobles
texto      = re.sub(' +', ' ', texto)
#quitando caracteres especiales
texto = re.sub(r"[^a-zA-Z0-9]+"," ",texto)
print(texto)
# Out:
# el gato con botas un molinero dejo como unica herencia a sus tres hijos su molino su burro y su gato el reparto fue bien simple ya que no se necesito llamar ni al abogado ni al notario pueshabrian consumido por el cobro todo el pobre patrimonioel mayor recibio el molino el segundo se quedo con el burro y al menor le toco solo elgato este se lamentaba de su misera herencia fdlis hermanos decia podran ganarse la vida convenientemente trabajando juntos lo que es yo despues de comerme a mi gato y de hacerme un manguito con su piel me morirede hambre el gato que escuchaba estas palabras pero se hacia el desentendido le dijo en tono serio y pausado no debes afligirte mi senor solo tienes que proporcionarme una bolsa y un par de botaspara andar por entre los matorrales y veras que tu herencia no es tan pobre como piensas aunque el amo del gato no abrigaba sobre esto grandes ilusiones aunque le habiavisto dar tantas muestras de agilidad para cazar ratas y ratones colgarse de los pies esconderse en la harina para hacerse el muerto que no desespero de verse socorrido porel en su miseria cuando el gato tuvo lo que habia pedido se calzo las botas y echandose la bosa tras el cuellosujeto los cordones de esta con las dospatas delanteras y se dirigio a un campo donde habia muchos conejos se puso a recoger hierbas las metio en su saco y se tendio en el suelo como si estuvieramuerto aguardo a que algun conejillo poco conocedor aun de las astucias de estemundo viniera a meter su hocico en la bolsa para comer lo que habia dentro apenas sehabia recostado cuando vio un atolondrado conejillo que se metia en el saco y elmaestro gato tirando los cordones lo encerro y lo mato sin misericordia muy ufano con su presa fue al palacio del rey ypidio hablar con el lo hicieron subir a los aposentos de su majestad dondeal entrar hizo una gran reverencia ante el rey y le dijo he aqui majestad un conejo de campo que el senor marques de carabas era el nombreque invento para su amo me ha encargado obsequiarle de su parte oile a tu amo respondio el rey que le doy las gracias y que me agrada mucho en otra ocasion se oculto en un trigal dejando siempre su saco abierto y cuando en el entrarondos perdices tiro los cordones y las cazo fue en seguida a ofrendarlas al rey tal como habia hecho conel conejo de campo el reyrecibio con agrado las dos perdices yordeno quele diesen de beber el gato continuo durante dos o tres meses llevando al rey obsequios de parte de su amo un dia supo que el rey iria a pasear a orillas del rio con su hija la mas hermosaprincesa del mundo y le dijo a su amo sigues mi consejo tu fortuna estaraasegurada tienes que banarte en el rio en el sitio que te mostrare y en seguidayo hare lo demas el marques de carabas hizo lo quesu gato le aconsejo sin saber de que serviria mientras se estaba banando el rey paso por ahi y el gato se puso a gritar con todas susfuerzas socorro socorro el senor marques de carabas se esta ahogandoa oir el grito el rey asomo la cabezala portezuela y reconociendo al gatoque tantas veces le habia llevado obsequios ordeno a sus guardias que acudieranrapidamente a socorrer al marques de carabas mientras sacaban del rio al pobre marques el gato se acerco a la carroza y le dijoal rey que cuando su amo se estaba banando unos ladrones se ilevaron sus ropas a pesar deque el al ver los grito con todas sus fuerzas auxilio ladrones auxilio e picaro del gato las habia escondido debajo de una enorme piedra el rey ordeno de inmediato a los encargados de su guardarropa que fuesen en busca de susmas bellas vestiduras para el senor marques de caraba el rey le hizo mil atenciones y como el hermoso traje que le acababan de dar realzabasu figura ya que era apuesto y bien formado la hija del rey lo encontro desu agrado basto que el marques de carabas le dirigiera dos o tres miradas sumamenterespetuosas y algo tiernas y ella quedo locamente enamorada el rey quiso que subiera a su carroza y lo acompanara en el paseo el gatoencantado al ver que su  ...

# %% [markdown]
# ##P1. entendiendo el texto

# %%
print('el texto tiene longitud de:{} caracteres'. format(len(texto)))
vocab = sorted(set(texto))
print('el texto esta compuesto de estos :{} caracteres'. format(len(vocab)))
print(vocab)
# Out:
# el texto tiene longitud de:7808 caracteres
# el texto esta compuesto de estos :25 caracteres
# [' ', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'v', 'x', 'y', 'z']

# %% [markdown]
# ##P2. pasar el texto a números
#
# ---
# as redes neuronales solo procesan valores numéricos, no letras, por tanto tenemos que traducir los caracteres a representación numérica. Para ello crearemos dos “tablas de traducción”: una de caracteres a números y otra de números a caracteres

# %%
char2idx = {u:i for i, u in enumerate(vocab)} # asignamos un número a cada vocablo
idx2char = np.array(vocab)
#-----------revisando las conversiones

#for char,_ in zip(char2idx, range(len(vocab))):
    #print(' {:4s}: {:3d},'.format(repr(char),char2idx[char]))

#pasamos todo el texto a números
texto_como_entero= np.array([char2idx[c] for c in texto])
print('texto: {}'.format(repr(texto[:100])))
print('{}'.format(repr(texto_como_entero[:100])))
# Out:
# texto: 'el gato con botas un molinero dejo como unica herencia a sus tres hijos su molino su burro y su gato'
# array([ 5, 11,  0,  7,  1, 19, 14,  0,  3, 14, 13,  0,  2, 14, 19,  1, 18,
#         0, 20, 13,  0, 12, 14, 11,  9, 13,  5, 17, 14,  0,  4,  5, 10, 14,
#         0,  3, 14, 12, 14,  0, 20, 13,  9,  3,  1,  0,  8,  5, 17,  5, 13,
#         3,  9,  1,  0,  1,  0, 18, 20, 18,  0, 19, 17,  5, 18,  0,  8,  9,
#        10, 14, 18,  0, 18, 20,  0, 12, 14, 11,  9, 13, 14,  0, 18, 20,  0,
#         2, 20, 17, 17, 14,  0, 23,  0, 18, 20,  0,  7,  1, 19, 14])

# %% [markdown]
# ###P2.1 exportar vocablos y matriz de numerica
#
# ---
#
# exporta en un CSV para usarlo cuando se cargue el modelo en otra instancia

# %%
rows=[]
columns=['num','vocab']
for i, voc in enumerate(vocab):
  #print(i,'-->', voc)
  rows.append([i,voc])
df= pd.DataFrame(columns=['num','vocab'],data=rows)
df.head(10)
df.to_csv('data_vocab.csv',index=False)

# %% [markdown]
# ##P3. preparar los datos para ser usados en la RNN

# %%
char_dataset= tf.data.Dataset.from_tensor_slices(texto_como_entero)
#cantidad de secuencia de caracteres
secu_length=50
#creamos secuencias de maximo 100 caractereres
secuencias= char_dataset.batch(secu_length+1, drop_remainder=True)
for item in secuencias.take(10):
  print(repr(''.join(idx2char[item.numpy()])))
# Out:
# 'el gato con botas un molinero dejo como unica heren'
# 'cia a sus tres hijos su molino su burro y su gato e'
# 'l reparto fue bien simple ya que no se necesito lla'
# 'mar ni al abogado ni al notario pueshabrian consumi'
# 'do por el cobro todo el pobre patrimonioel mayor re'
# 'cibio el molino el segundo se quedo con el burro y '
# 'al menor le toco solo elgato este se lamentaba de s'
# 'u misera herencia fdlis hermanos decia podran ganar'
# 'se la vida convenientemente trabajando juntos lo qu'
# 'e es yo despues de comerme a mi gato y de hacerme u'

# %% [markdown]
# ###P3.1 separar los datos en agrupamientos (batches)

# %%
#funcion para obtener el conjunto de datos de trainning
def split_input_target(chunk):
  input_text = chunk[:-1]
  target_text= chunk[1:]
  return input_text, target_text

dataset  = secuencias.map(split_input_target)
#el dataset contiene un conjunto de parejas de secuencia de texto
#(con la representación numérica de los caracteres), donde el 
#primer componente de la pareja contiene un paquete con una secuencia 
#de 100 caracteres del texto original y la segunda su correspondiente salida, 
#también de 100 caracteres. )
for input_example, target_example in dataset.take(1):
  print('input data: ', repr(''.join(idx2char[input_example.numpy()])))
  print('Target data: ', repr(''.join(idx2char[target_example.numpy()])))
# Out:
# input data:  'el gato con botas un molinero dejo como unica here'
# Target data:  'l gato con botas un molinero dejo como unica heren'

# %%
#imprimimos el tensor del dataset
print(dataset)
#Hyper-Parametros para entrenamiento  de una rede neuronal 
#   -los datos se agrupan en batch
BATCH_SIZE= 64
#    -Tamaño de memoria disponible 
BUFFER_SIZE=10000
dataset= dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
print (dataset)
#En el tensor dataset disponemos los datos de entrenamiento
#con agrupamienttos (batches) compuestos de 64 parejas de secuencias 
#de 100 integers de 64 bits que representan el carácter correspondiente 
#en el vocabulario.
# Out:
# <MapDataset shapes: ((50,), (50,)), types: (tf.int64, tf.int64)>
# <BatchDataset shapes: ((64, 50), (64, 50)), types: (tf.int64, tf.int64)>

# %% [markdown]
# ##P4.Construcción del modelo RNN
#
# ---
# Para construir el modelo usaremos tf.keras.Sequential. Usaremos una versión mínima de RNN, que contenga solo una capa LSTM y 3 capas.

# %%
#como es un problema de clasificación estándar 
#para el que debemos definir la función de Lossy el optimizador.
def lossy(labels, logits):
  return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def create_model(vocab_size, embedding_dim, rnn_units, batch_size):
  #creando el modelo
  model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim,
                              batch_input_shape=[batch_size, None]),
    tf.keras.layers.LSTM(rnn_units,
                         return_sequences=True,
                         stateful=True,
                         recurrent_initializer='glorot_uniform'),
    tf.keras.layers.Dense(vocab_size)                               
  ])
  #En cuanto al optimizador usaremos tf.keras.optimizers.Adam 
  #con los argumentos por defecto del optimizador Adam. 
  model.compile(optimizer='adam',
              loss=lossy,
              metrics=['accuracy'])
  return model
vocab_size= len(vocab)
#dimensiones de los vectores que tendrá la capa.
embedding_dim= 256
#cantidad de neuronas
rnn_units=1024
#creamos nuestra red neuronal RNN
model=create_model(vocab_size   =vocab_size,
                  embedding_dim =embedding_dim,
                  rnn_units     =rnn_units,
                  batch_size    =BATCH_SIZE)
#summary()para visualizar la estructura del modelo
model.summary()
#resultados=  -La capa LSTM consta más de 5 millones de parametros)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (64, None, 256)           6400
#
#  lstm_1 (LSTM)               (64, None, 1024)          5246976
#
#  dense_1 (Dense)             (64, None, 25)            25625
#
# =================================================================
# Total params: 5,279,001
# Trainable params: 5,279,001
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###P4.1 Creando chekpoints
#
# ---
# una técnica de tolerancia de fallos para procesos cuyo tiempo de ejecución es muy largo. La idea es guardar una instantánea del estado del sistema periódicamente para recuperar desde ese punto la ejecución en caso de fallo del sistema.
#
# ---
# los crearemos en google drive para mejorar la capacidad de reentrenamiento de la red

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
checkpoint_dir='/content/gdrive/MyDrive/Colab Notebooks/P2_Deep_Learning/PLN/Redes neuronales recurrentes (RNN)/checkpointsV2/'
checkpoint_prefix= os.path.join(checkpoint_dir,"cp_{epoch:04d}.ckpt")


cp_callback=tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix,
                                               monitor='loss',
                                               verbose=1,
                                               save_weights_only=True,
                                               save_best_only=True,
                                               mode='auto')

# %% [markdown]
# ###P4.2 entrenando

# %% [markdown]
# ####P4.2a entrenando para usar chekpoints
#
#
# ---
#
# *   https://keras.io/api/callbacks/model_checkpoint/
# *   https://towardsdatascience.com/checkpointing-deep-learning-models-in-keras-a652570b8de6

# %%
EPOCHS=100
history=model.fit(dataset, 
                  epochs=EPOCHS, 
                  verbose=1,
                  callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 2/2 [==============================] - ETA: 0s - loss: 3.1976 - accuracy: 0.1045
# Epoch 00001: loss improved from inf to 3.19759, saving model to /content/gdrive/MyDrive/Colab Notebooks/P2_Deep_Learning/PLN/Redes neuronales recurrentes (RNN)/checkpointsV2/cp_0001.ckpt
# 2/2 [==============================] - 4s 2s/step - loss: 3.1976 - accuracy: 0.1045
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-756226eabe24> in <module>()
#       3                   epochs=EPOCHS,
#       4                   verbose=1,
# ----> 5                   callbacks=[cp_callback])
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1203       logs = None
#    1204       for epoch, iterator in data_handler.enumerate_epochs():
# -> 1205         self.reset_metrics()
#    1206         callbacks.on_epoch_begin(epoch)
#    1207         with data_handler.catch_stop_iteration():
#
# KeyboardInterrupt:

# %% [markdown]
# #####4.2a-1 entrenando desde un checkpoint
#
# ---
# Desde la carpeta que optamos guardar los checkpoints
#
# *   el archivo .data es el archivo que contiene nuestras variables de entrenamiento y vamos a ir tras él.
# *   el archivo checkpoint, simplemente mantiene un registro de los últimos archivos de punto de control guardados

# %%
#creamos un modelo con iguales caracteristicas al 1° modelo
model=create_model(vocab_size   =vocab_size,
                  embedding_dim =embedding_dim,
                  rnn_units     =rnn_units,
                  batch_size    =BATCH_SIZE)

#buscamos el ultimo checkpoint de entrenamiento
latest = tf.train.latest_checkpoint(checkpoint_dir)
print(latest)
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/P2_Deep_Learning/PLN/Redes neuronales recurrentes (RNN)/checkpoints_test1/cp_0015.ckpt

# %%
# cargamos los pesos al nuevo modelo (estos valores tienes una variación de un 10%)
model.load_weights(latest)
# continuamos el entrenamiento desde el checkpoint en que quedamos
history2=model.fit(dataset, 
                    epochs=50, 
                    verbose=1,
                    callbacks=[cp_callback])

# %% [markdown]
# ####P4.2b entrenando con tensorboard (opcional)

# %% [markdown]
# #####Activando TENSORBOARD
#
# ---
# (DASHBOARD para ver el proceso de entrenamiento)

# %%
# You can change the directory name
LOG_DIR = 'tb_logs'

# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

import os
if not os.path.exists(LOG_DIR):
  os.makedirs(LOG_DIR)
  
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR))

get_ipython().system_raw('./ngrok http 6006 &')

# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# --2021-11-17 22:51:37--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 54.237.133.81, 18.205.222.128, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.2’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  2.61MB/s    in 12s
#
# 2021-11-17 22:51:50 (1.14 MB/s) - ‘ngrok-stable-linux-amd64.zip.2’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ngrok
# http://47d1-104-199-163-197.ngrok.io

# %%
tbCallBack = tf.keras.callbacks.TensorBoard(log_dir=LOG_DIR, 
                         histogram_freq=1,
                         write_graph=True,
                         write_grads=True,
                         batch_size=BATCH_SIZE,
                         write_images=True)
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.

# %% [markdown]
# #####Fit

# %%
#model.fit(X, y, epochs=50, batch_size=64, callbacks=callbacks_list)
history_TB=model2.fit(dataset, 
                    epochs=200, 
                    verbose=1,
                    callbacks=[tbCallBack])
# Out:
# 52/52 [==============================] - 15s 283ms/step - loss: 0.1148 - accuracy: 0.9777
# Epoch 195/200
# 52/52 [==============================] - 15s 282ms/step - loss: 0.1139 - accuracy: 0.9777
# Epoch 196/200
# 52/52 [==============================] - 15s 283ms/step - loss: 0.1129 - accuracy: 0.9779
# Epoch 197/200
# 52/52 [==============================] - 15s 283ms/step - loss: 0.1115 - accuracy: 0.9780
# Epoch 198/200
# 52/52 [==============================] - 16s 283ms/step - loss: 0.1112 - accuracy: 0.9780
# Epoch 199/200
# 52/52 [==============================] - 15s 282ms/step - loss: 0.1123 - accuracy: 0.9779
# Epoch 200/200
# 52/52 [==============================] - 15s 282ms/step - loss: 0.1101 - accuracy: 0.9782

# %% [markdown]
# ##P5. Generando texto nuevo usando la RNN

# %%
#creamos un modelo tomando como base el ultimo checkpoint
model = build_model(vocab_size, embedding_dim, rnn_units, batch_size=1)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1,None]))

# %%
#funcion para generar texto
def generate_text(model, start_string):
  #definimos cuantos tensores/cantidad de texto generaremos
  num_generate=500
  #convertimos el texto en números
  input_eval=[char2idx[s] for s in start_string]
  input_eval= tf.expand_dims (input_eval,0)
  text_generated = []

  temperature = 0.2  #(0.0 a  1) entre más alta la temperatura más creatividad al modelo, pero tambien más errores ortograficos.
  model.reset_states() #bucle para generar caracteres, mediante predicciones
  for i in range(num_generate):
    predictions = model(input_eval)
    predictions = tf.squeeze(predictions, 0)
    predictions = predictions / temperature
    predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()
    input_eval= tf.expand_dims([predicted_id],0)
    text_generated.append (idx2char[predicted_id])
  
  return (start_string+ ''.join(text_generated))

# %% [markdown]
# ###P5.1 generando texto

# %%
print(generate_text(model, start_string=u"la colonia europea"))
# Out:
# la colonia europea, que siguió a los heroísmos de los primeros exploradores, fue
# acompañado, en otro plano, por la aventura. la aventura personal. en los primeros libros de
# melancolía, y por extraño que parezca, no nos sentíamos
# demasiado mal tras la terrible experiencia del valor y atractivo aventurero); y por fin, inevitablemente,
# una lucha con la muerte, que es a la vez concreta y una alegoría ún que el pueblo kukuana preserva a sus reyes
# muertos desde tiempo inmemorial. los petrifica. no llegué a descubr

# %% [markdown]
# ##P6.exportando modelo
#
# ---
# Guardamos y Serializamos el Modelo (con esto ya podemos vender nuestro modelo de predicción de texto según lo aprendido por nuestra RNN).

# %%
from keras.models import model_from_json
import os
dir_export= '/content/gdrive/MyDrive/Colab Notebooks/P2_Deep_Learning/PLN/Redes neuronales recurrentes (RNN)/Modelos'
#dir_export= os.path.join(dir_drive)
# Serializamos el modelo en forma JSON
model_json = model.to_json()
with open(os.path.join(dir_export,'RNN_LasMinasDelReySalomon_json.json'), 'w') as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(os.path.join(dir_export,'RNN_LasMinasDelReySalomon_pesos.hdf5'))
model.save(os.path.join(dir_export,'RNN_LasMinasDelReySalomon_model.h5'))
print("modelo salvado en Drive de google")
# Out:
# modelo salvado en Drive de google

# %% [markdown]
# ##P7.Cargando un modelo serializado

# %% [markdown]
# ###P7.1 descargamos el modelo usando wget

# %%
# !wget https://github.com/michelBolivar/Deep_learning/blob/main/Corte2/cuento/cuento_1500/modelRNN_cuentos2_2.h5?raw=true \
      -O modelRNN_cuentos2_2.h5

# %% [markdown]
# ####P7.1a descargamos el modelo usando PYRIND & URLLIB (OPCIONAL)

# %%
# !pip install pyprind
# Out:
# Collecting pyprind
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Installing collected packages: pyprind
# Successfully installed pyprind-2.11.3

# %%
def reporthook(count, block_size, total_size):
    global start_time
    if count == 0:
        start_time = time.time()
        return
    duration = time.time() - start_time
    progress_size = int(count * block_size)
    speed = progress_size / (1024.**2 * duration)
    percent = count * block_size * 100. / total_size
    sys.stdout.write("\r%d%% | %d MB | %.2f MB/s | %d segundos transcurrido" %
                    (percent, progress_size / (1024.**2), speed, duration))
    sys.stdout.flush()

import urllib.request
url_github_Model='https://github.com/luisFernandoCastellanosG/Machine_learning/blob/master/DeepLearning/PLN/recurrent_network_RNN/Modelos/RNN_LasMinasDelReySalomon_model.h5?raw=true'
urllib.request.urlretrieve(url_github_Model,
                           'RNN_LasMinasDelReySalomon_model2.h5', 
                           reporthook)
# Out:
# 100% | 61 MB | 4.15 MB/s | 14 segundos transcurrido
# ('RNN_LasMinasDelReySalomon_model2.h5',
#  <http.client.HTTPMessage at 0x7fa210031590>)

# %% [markdown]
# ###P7.2 instanciamos el modelo descargado

# %%
new_model = tf.keras.models.load_model('/content/modelRNN_cuentos2_2.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/luisFernandoCastellanosG/Machine_learning/master/DeepLearning/PLN/recurrent_network_RNN/Modelos/data_vocab.csv")
df2.head()
# Out:
#    num vocab
# 0    0
# 1    1     0
# 2    2     1
# 3    3     2
# 4    4     3

# %%
#funcion para generar texto
def generate_text(model, start_string):
  #definimos cuantos tensores/cantidad de texto generaremos
  num_generate=500
  #convertimos el texto en números
  input_eval  = [char2idx[s] for s in start_string]
  input_eval  = tf.expand_dims (input_eval,0)
  text_generated = []

  temperature = 0.2  #(0.0 a  1) entre más alta la temperatura más creatividad al modelo, pero tambien más errores ortograficos.
  model.reset_states() #bucle para generar caracteres, mediante predicciones
  for i in range(num_generate):
    predictions = model(input_eval)
    predictions = tf.squeeze(predictions, 0)
    predictions = predictions / temperature
    predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()
    input_eval= tf.expand_dims([predicted_id],0)
    text_generated.append (idx2char[predicted_id])
  
  return (start_string+ ''.join(text_generated))

# %%
print(generate_text(new_model, start_string=u"los fantasmas de "))
# Out:
# los fantasmas de 9a 7dgdc9a 9g5 jc ?db6g9 5a9;g9 n _dk\5a) 5hw 7dbd hj 9hedh5 9g5 a5 ig5iy 89 7d;9ga5 9c hjh 6g5odh- e9gd 9c 9a b\hbd \chi5ci9 589a;jc85 h9 5bedaa5 h9 gdbew5 89 :dgb5 \cd7j5 7dcig5 a5h e\98g5h 89a e5h58\od b\9cig5h 9a zai\bd n e5ivi\7d g9o5;58d) 9a d69hd 7d7\c9gd) 89h5e5g97w5 e9h585b9ci9 89 a5 k\hi5 9c 9a hdb6gwd 9hi5cfj9) a5h :a5ji5h n i5b6dg9h 9cbj897\9gdc) n adh 79;58dg9h g5ndh 89 a5h gj\c5h h9 9h:jb5gdc 5a \chi5ci9) 89_5c8d a5 5a895 89 a5 b5a8\7\yc 89hda585 n hda\i5g\5 65_d adh i9cj9h g5ndh 8
